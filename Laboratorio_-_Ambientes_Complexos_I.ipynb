# %% [markdown]
# # Laboratório Prático - Ambientes Complexos I
#
# ---

# %% [markdown]
# ## Ajustando ambiente

# %%
import math
import random

# %% [markdown]
# ## Motivação

# %% [markdown]
# Estudar algoritmos de busca local, como a Subida de Encosta (Hill Climbing) e o Recozimento Simulado (Simulated Annealing), é fundamental na Inteligência Artificial porque eles oferecem abordagens eficientes para problemas complexos de otimização, onde o foco não é o caminho percorrido, mas sim a descoberta do melhor estado final com base em uma função objetivo. Conceitualmente, a busca local navega pelo espaço de estados avaliando vizinhos para encontrar o máximo ou mínimo global, destacando-se por utilizar pouca memória. Como a Subida de Encosta clássica é "gananciosa" e frequentemente fica presa em picos falsos (máximos locais), suas variantes — como a busca estocástica, a de primeira escolha e a com reinício aleatório — introduzem aleatoriedade para escapar dessas armadilhas e aumentar a resiliência do algoritmo. O Recozimento Simulado aprimora essa fuga ao permitir estrategicamente movimentos que temporariamente pioram a avaliação (movimentos para baixo), reduzindo a probabilidade dessas escolhas ruins ao longo do tempo conforme uma "temperatura" diminui, até o sistema estabilizar na solução ideal. O domínio dessas metodologias é indispensável, pois elas não apenas resolvem problemas práticos complexos de engenharia, como o design de circuitos integrados (layout VLSI), o escalonamento de chão de fábrica e a otimização de redes de telecomunicações, mas seus princípios de exploração e descida de gradiente também fundamentam a otimização contínua e convexa, que são a base matemática para resolver problemas cruciais modernos em aprendizado de máquina (machine learning) e teoria de controle.

# %% [markdown]
# ## Objetivos de Aprendizagem

# %% [markdown]
# * Representar o problema das 8 rainhas como busca local.
# * Ler o estado do tabuleiro usando uma lista simples.
# * Entender a função objetivo baseada em rainhas apaziguadas.
# * Implementar o Hill Climbing padrão.
# * Comparar as variantes estocástica e de primeira escolha.
# * Compreender o papel do reinício aleatório.
# * Explicar como a temperatura atua no Simulated Annealing.
# * Observar diferenças entre os algoritmos implementados.

# %% [markdown]
# ## Implementação

# %% [markdown]
# O **Problema das 8 Rainhas** é um desafio clássico de otimização na busca local em que o objetivo é posicionar oito rainhas em um tabuleiro sem que se ataquem, importando apenas a configuração do estado final e não o caminho percorrido para alcançá-lo. Computacionalmente, adota-se uma formulação de estado completo (movendo apenas uma rainha por coluna de cada vez) e utiliza-se uma função de custo heurística focada em minimizar o número de pares de rainhas se atacando. Como a "paisagem" desse problema é repleta de máximos locais — estados onde restam ataques, mas mover qualquer peça isoladamente piora a situação —, a subida de encosta tradicional falha em 86% das tentativas ao ficar presa nesses picos falsos. Para contornar essa limitação com extrema eficácia, aplica-se a **subida de encosta com reinício aleatório**, uma abordagem que simplesmente abandona os tabuleiros estagnados e recomeça a busca do zero a partir de novas configurações aleatórias até encontrar a solução perfeita.

# %% [markdown]
# <details>
# <summary>O caminho percorrido pelo algoritmo importa, ou apenas o estado final?</summary>
#
# Em busca local, o foco principal costuma estar no **estado final**, e não no caminho percorrido. O objetivo é encontrar uma configuração boa ou ótima usando apenas informações locais sobre os vizinhos do estado atual. Isso significa que, na maioria dos casos, pouco importa se o algoritmo passou por muitos estados intermediários diferentes, desde que consiga chegar a uma boa solução. Ainda assim, o caminho pode ser relevante quando queremos comparar eficiência entre algoritmos, observar quantas iterações foram necessárias ou entender por que uma estratégia ficou presa em um máximo local.
#
# </details>

# %% [markdown]
# ### Representação do Estado

# %% [markdown]
# Para solucionar esse problema, vamos precisar construir uma abstração que simplifique as configurações de estados. Por exemplo, em vez de desenhar o tabuleiro inteiro a cada passo, vamos guardar apenas a posição de cada rainha em uma lista. Essa escolha deixa o problema muito mais simples para o algoritmo manipular.
#
# A ideia é a seguinte:
#
# * Cada **posição da lista** representa uma **coluna** do tabuleiro.
# * Cada **valor armazenado** nessa posição representa a **linha** onde está a rainha daquela coluna.
# * Como há exatamente **uma rainha por coluna**, uma lista com 8 números já descreve completamente um tabuleiro.
#
# Por exemplo, no estado `[6, 4, 2, 0, 5, 7, 1, 3]`:
#
# * na coluna `0`, a rainha está na linha `6`
# * na coluna `1`, a rainha está na linha `4`
# * na coluna `2`, a rainha está na linha `2`
# * na coluna `3`, a rainha está na linha `0`
# * na coluna `4`, a rainha está na linha `5`
# * na coluna `5`, a rainha está na linha `7`
# * na coluna `6`, a rainha está na linha `1`
# * na coluna `7`, a rainha está na linha `3`
#
# Uma forma intuitiva de ler essa lista é pensar assim: o algoritmo olha para cada coluna e pergunta "em que linha devo colocar a rainha desta coluna?". Isso também explica por que gerar um vizinho é simples: basta escolher **uma coluna** e trocar o valor da **linha** daquela rainha. Ou seja, mover uma rainha no problema significa alterar apenas um número da lista.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Importante:** seguimos a indexação do Python. Portanto, a primeira coluna é a `0`, a segunda é a `1` e assim por diante. O mesmo vale para as linhas.

# %% [markdown]
# <details>
# <summary>O que ganhamos ao representar o estado como uma lista, em vez de um tabuleiro completo 8x8?</summary>
#
# Representar o estado como uma lista torna o problema muito mais simples de manipular computacionalmente. Em vez de guardar 64 posições do tabuleiro, guardamos apenas 8 valores, um para cada coluna. Isso reduz o custo de memória, facilita a geração de vizinhos e deixa o código mais legível. Além disso, como assumimos exatamente uma rainha por coluna, a lista já contém toda a informação importante para a busca local. Assim, mover uma rainha significa apenas alterar um número da lista, o que é muito mais prático do que reconstruir ou percorrer um tabuleiro completo a cada passo.
#
# </details>

# %% [markdown]
# ### Função de Objetivo
#
# Para o Hill Climbing e para o Simulated Annealing, precisamos de uma função que diga o quão boa é uma configuração. Neste laboratório, vamos usar uma medida mais intuitiva: contar quantas rainhas estão **apaziguadas**, isto é, quantas não estão sendo atacadas por nenhuma outra. Quanto maior essa pontuação, melhor o estado. A solução ideal é aquela em que o valor chega a `8`.

# %%
def count_peaceful_queens(board):
    """Conta quantas rainhas nao atacam nenhuma outra rainha no tabuleiro."""
    peaceful_queens = 0
    n = len(board)

    for i in range(n):
        under_attack = False
        for j in range(n):
            if i == j:
                continue

            same_row = board[i] == board[j]
            same_diagonal = abs(i - j) == abs(board[i] - board[j])

            if same_row or same_diagonal:
                under_attack = True
                break

        if not under_attack:
            peaceful_queens += 1

    return peaceful_queens

# %% [markdown]
# <details>
# <summary>Quais são as vantagens e limitações de usar “rainhas apaziguadas” como função objetivo?</summary>
#
# A principal vantagem é a **intuição**. Quanto maior a pontuação, melhor o estado, e a solução ideal fica fácil de interpretar: queremos chegar a `8` rainhas apaziguadas. Isso costuma ser mais natural para os alunos do que pensar em minimizar conflitos. A limitação é que essa função objetivo não mede todos os estados intermediários com a mesma precisão possível de outras heurísticas. Dois tabuleiros diferentes podem ter a mesma quantidade de rainhas apaziguadas, mesmo que um deles esteja estruturalmente mais perto da solução final. Ou seja, a heurística é didática e útil, mas não necessariamente a mais informativa para todos os movimentos da busca.
#
# </details>

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def count_peaceful_queens(board):**
# > Define a função que recebe a configuração do tabuleiro e retorna o total de rainhas "em paz" (seguras).
#
# 3. **peaceful_queens = 0**
# > Inicializa o acumulador que contará cada rainha que não estiver sob ataque.
#
# 4. **n = len(board)**
# > Identifica o tamanho do tabuleiro (número de rainhas).
#
# 6. **for i in range(n):**
# > Inicia um loop para analisar cada rainha individualmente (cada coluna `i`).
#
# 7. **under_attack = False**
# > Define um sinalizador (flag) assumindo que a rainha atual está segura até que se prove o contrário.
#
# 8. **for j in range(n):**
# > Inicia um segundo loop para comparar a rainha atual `i` com todas as outras rainhas `j` do tabuleiro.
#
# 9. **if i == j: continue**
# > Pula a comparação se a rainha for comparada com ela mesma.
#
# 12. **same_row = board[i] == board[j]**
# > Verifica se a rainha `j` está na mesma linha que a rainha `i`. Se os valores forem iguais, as rainhas estão na mesma linha horizontal.
#
# 13. **same_diagonal = abs(i - j) == abs(board[i] - board[j])**
# > Verifica se a rainha `j` está na mesma diagonal que a rainha `i` usando a diferença absoluta entre colunas e linhas. Se as distâncias forem idênticas, elas formam uma linha de 45 graus, caracterizando ataque diagonal.
#
# 15. **if same_row or same_diagonal:**
# > Se houver conflito em linha ou diagonal, a rainha `i` não está "em paz".
#
# 16. **under_attack = True**
# > Altera o sinalizador indicando que a rainha atual está sofrendo ataque.
#
# 17. **break**
# > Interrompe o loop interno precocemente, pois não é necessário verificar outras rainhas se já sabemos que esta está sob ataque.
#
# 19. **if not under_attack:**
# > Após verificar todas as outras rainhas, se o sinalizador continuar `False`, a rainha está segura.
#
# 20. **peaceful_queens += 1**
# > Incrementa o contador de rainhas apaziguadas.
#
# 22. **return peaceful_queens**
# > Retorna o total final. No cenário ideal, este valor será igual a `n`.
#
# </details>

# %% [markdown]
# ### Hill Climbing Padrão (inclinação máxima)

# %% [markdown]
# O Hill Climbing puro é como um alpinista com amnésia tentando escalar o Monte Everest sob um forte nevoeiro. Ele não consegue enxergar o topo da montanha nem lembrar por onde passou; apenas tateia o terreno imediatamente ao seu redor e dá o próximo passo na direção mais íngreme que encontrar. Se ele chegar ao topo de um pequeno morro, ele não encontra nenhum vizinho mais alto e para, achando que chegou ao cume absoluto, ignorando completamente que a verdadeira montanha pode estar logo ao lado.

# %%
def hill_climbing(num_queens):
    """Algoritmo de Hill Climbing maximizando rainhas apaziguadas."""

    current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]
    current_score = count_peaceful_queens(current_board)

    while True:
        best_neighbor_board = list(current_board)
        best_neighbor_score = current_score

        for col in range(num_queens):
            for new_row in range(num_queens):
                neighbor = list(current_board)
                neighbor[col] = new_row
                neighbor_score = count_peaceful_queens(neighbor)

                if neighbor_score > best_neighbor_score:
                    best_neighbor_score = neighbor_score
                    best_neighbor_board = neighbor

        if best_neighbor_score > current_score:
            current_board = best_neighbor_board
            current_score = best_neighbor_score
            print(f"Moving to: {current_board} | Peaceful queens: {current_score}")
        else:
            print("\nAlgorithm stopped. Local maximum or solution found.")
            return current_board, current_score

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def hill_climbing(num_queens):**
# > Define a função principal que tenta resolver o problema das rainhas usando otimização local.
#
# 4. **current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]**
# > Gera um estado inicial aleatório, colocando uma rainha em cada coluna em uma linha sorteada.
#
# 5. **current_score = count_peaceful_queens(current_board)**
# > Calcula a pontuação inicial (quantas rainhas estão seguras no tabuleiro aleatório).
#
# 7. **while True:**
# > Inicia o loop de busca. O algoritmo continuará "subindo a encosta" até não encontrar mais melhorias.
#
# 8. **best_neighbor_board = list(current_board)**
# > Cria uma cópia para armazenar o melhor movimento encontrado ao redor da posição atual.
#
# 11. **for col in range(num_queens):**
# > Começa a explorar a vizinhança: percorre cada coluna do tabuleiro.
#
# 12. **for new_row in range(num_queens):**
# > Para cada coluna, testa todas as outras linhas possíveis para a rainha.
#
# 14. **neighbor[col] = new_row**
# > Cria um "vizinho" alterando a posição de apenas uma rainha.
#
# 15. **neighbor_score = count_peaceful_queens(neighbor)**
# > Avalia quão boa é essa nova configuração sugerida.
#
# 17. **if neighbor_score > best_neighbor_score:**
# > Se o vizinho for melhor que o melhor encontrado até agora nesta rodada, ele se torna a nova referência.
#
# 21. **if best_neighbor_score > current_score:**
# > Após testar todos os vizinhos, verifica se o melhor deles é superior ao estado atual.
#
# 22. **current_board = best_neighbor_board**
# > Se houver melhoria, o algoritmo "anda" para esse novo tabuleiro e continua a busca.
#
# 25. **else:**
# > Se nenhum vizinho for melhor que o atual, o algoritmo atingiu um **máximo local** ou a solução ideal.
#
# 27. **return current_board, current_score**
# > Encerra a execução devolvendo o melhor tabuleiro alcançado e sua pontuação.
#
# </details>

# %% [markdown]
# ### Hill Climbing Estocástico

# %% [markdown]
# O Hill Climbing puro é obcecado em pegar sempre o caminho mais íngreme disponível. O Hill Climbing Estocástico adiciona uma estratégia mais relaxada: o alpinista olha para todos os caminhos que levam para cima e escolhe um deles aleatoriamente, sendo que os caminhos mais inclinados têm apenas uma probabilidade maior de serem escolhidos. Sendo assim, a ideia é que, ao não ser estritamente ganancioso e perfeito em suas escolhas, o algoritmo converge um pouco mais devagar, mas tem muito mais chances de evitar caminhos enganosos e encontrar picos melhores na cordilheira.

# %%
def stochastic_hill_climbing(num_queens):
    """Hill Climbing Estocástico maximizando rainhas apaziguadas."""

    current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]
    current_score = count_peaceful_queens(current_board)

    while True:
        improving_neighbors = []
        improvements = []

        for col in range(num_queens):
            for new_row in range(num_queens):
                neighbor = list(current_board)
                neighbor[col] = new_row
                neighbor_score = count_peaceful_queens(neighbor)

                if neighbor_score > current_score:
                    improving_neighbors.append((neighbor, neighbor_score))
                    improvements.append(neighbor_score - current_score)

        if not improving_neighbors:
            print("\nAlgorithm stopped. Local maximum or solution found.")
            return current_board, current_score

        next_board, next_score = random.choices(
            improving_neighbors,
            weights=improvements,
            k=1,
        )[0]

        current_board = next_board
        current_score = next_score
        print(f"Moving to: {current_board} | Peaceful queens: {current_score}")

# %% [markdown]
# <details>
# <summary>Em que sentido o Hill Climbing Estocástico é menos rígido do que o Hill Climbing padrão?</summary>
#
# No *Hill Climbing* padrão, o algoritmo sempre escolhe o melhor vizinho disponível. Isso o torna totalmente determinístico e rígido em cada passo local, dado o estado atual. No *Hill Climbing* Estocástico, essa rigidez diminui porque ele não exige escolher sempre a subida mais íngreme. Em vez disso, ele lista todos os vizinhos que trazem alguma melhoria e sorteia um deles.
#
# No código, a quebra dessa rigidez e o sorteio acontecem exatamente neste trecho:
#
# ```python
# next_board, next_score = random.choices(
#     improving_neighbors,
#     weights=improvements,
#     k=1,
# )
# ```
# Com o uso do comando `random.choices`, o algoritmo "gira uma roleta" para decidir o próximo passo. O parâmetro `weights=improvements` garante que a probabilidade de seleção varie de acordo com a inclinação da subida: movimentos que trazem uma melhoria maior ganham mais chances de serem sorteados, mas movimentos subótimos ainda mantêm uma probabilidade real de escolha. Assim, a busca continua “subindo”, mas com muito mais flexibilidade para explorar caminhos diferentes na paisagem de estados e evitar ficar presa rapidamente em máximos locais.
# </details>

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def stochastic_hill_climbing(num_queens):**
# > Define a variante estocástica do Hill Climbing, que continua buscando melhorias locais, mas não escolhe sempre o melhor vizinho.
#
# 4. **current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]**
# > Começa com um tabuleiro aleatório, como no Hill Climbing padrão.
#
# 8. **improving_neighbors = []**
# > Cria uma lista para guardar apenas os vizinhos que realmente melhoram a solução atual.
#
# 9. **improvements = []**
# > Guarda o tamanho da melhoria de cada vizinho, para que movimentos melhores tenham mais chance de serem escolhidos.
#
# 15. **neighbor_score = count_peaceful_queens(neighbor)**
# > Avalia cada vizinho usando a mesma função objetivo do laboratório.
#
# 17. **if neighbor_score > current_score:**
# > Filtra somente os vizinhos que sobem a encosta, isto é, os que aumentam o número de rainhas apaziguadas.
#
# 22. **if not improving_neighbors:**
# > Se não existir nenhum vizinho melhor, o algoritmo parou em um máximo local ou chegou à solução ótima.
#
# 26. **random.choices(..., weights=improvements, k=1)**
# > Sorteia um dos vizinhos melhores. Quanto maior a melhoria, maior a chance de ele ser escolhido.
#
# 32. **current_board = next_board**
# > Move o algoritmo para o vizinho sorteado e continua a busca.
#
# </details>

# %% [markdown]
# ### Hill Climbing de Primeira Escolha

# %% [markdown]
# Agora, imagine que o nosso alpinista está em um terreno tão complexo que ele tem milhares de opções de passos possíveis ao seu redor. Avaliar todas elas para montar probabilidades (como na variante estocástica) demoraria muito. O Hill Climbing de Primeira Escolha adiciona uma estratégia de ganho de desempenho computacional: o alpinista simplesmente sorteia direções aleatórias uma por uma e, assim que encontra a *primeira* direção que o leva para cima, ele dá o passo. Sendo assim, a ideia é manter a aleatoriedade da subida, mas economizando processamento ao não precisar listar e avaliar todos os milhares de vizinhos antes de se mover.

# %%
def first_choice_hill_climbing(num_queens, max_attempts=100):
    """Hill Climbing de Primeira Escolha maximizando rainhas apaziguadas."""

    current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]
    current_score = count_peaceful_queens(current_board)

    while True:
        found_better_neighbor = False

        for _ in range(max_attempts):
            col = random.randint(0, num_queens - 1)
            new_row = random.randint(0, num_queens - 1)

            neighbor = list(current_board)
            neighbor[col] = new_row
            neighbor_score = count_peaceful_queens(neighbor)

            if neighbor_score > current_score:
                current_board = neighbor
                current_score = neighbor_score
                found_better_neighbor = True
                print(f"Moving to: {current_board} | Peaceful queens: {current_score}")
                break

        if not found_better_neighbor:
            print("\nAlgorithm stopped. Local maximum or solution found.")
            return current_board, current_score

# %% [markdown]
# <details>
# <summary>O que o Hill Climbing de Primeira Escolha sacrifica e o que ele ganha em relação às outras variantes?</summary>
#
# Ele ganha **velocidade de decisão**. Como não precisa avaliar toda a vizinhança, ele gera sucessores aleatoriamente apenas até encontrar o primeiro que seja melhor que o estado atual, o que é uma excelente estratégia quando o espaço de vizinhos é muito grande (por exemplo, milhares de sucessores). Por outro lado, ele sacrifica a **qualidade na escolha local**. Como aceita a primeira melhora encontrada, ele pode deixar passar movimentos muito melhores que apareceriam se ele examinasse mais opções. Em troca de eficiência computacional, ele abre mão de uma decisão local mais informada.
#
# No código, essa característica central é perfeitamente representada pela condição de aceite seguida do comando `break`:
#
# ```python
# if neighbor_score > current_score:
#     current_board = neighbor
#     current_score = neighbor_score
#     found_better_neighbor = True
#
#     # O comando break interrompe a busca cega instantaneamente
#     break
# ```
#
# É exatamente esse `break` que garante a **velocidade** (ao encerrar o laço de tentativas na mesma hora) e que impõe o **sacrifício da qualidade** (pois impede que o algoritmo continue testando outras combinações que poderiam gerar um `neighbor_score` ainda mais alto na mesma vizinhança).
#
# </details>

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def first_choice_hill_climbing(num_queens, max_attempts=100):**
# > Define a variante de primeira escolha. Em vez de analisar toda a vizinhança, ela testa movimentos aleatórios até encontrar a primeira melhora.
#
# 4. **current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]**
# > Gera um estado inicial aleatório.
#
# 8. **found_better_neighbor = False**
# > Marca se, naquela rodada, algum vizinho melhor foi encontrado.
#
# 10. **for _ in range(max_attempts):**
# > Limita quantas tentativas aleatórias serão feitas antes de desistir da rodada atual.
#
# 11. **col = random.randint(0, num_queens - 1)**
# > Escolhe aleatoriamente uma coluna para mover uma rainha.
#
# 12. **new_row = random.randint(0, num_queens - 1)**
# > Escolhe uma nova linha para essa rainha.
#
# 16. **neighbor_score = count_peaceful_queens(neighbor)**
# > Avalia a qualidade do vizinho sorteado.
#
# 18. **if neighbor_score > current_score:**
# > Se esse primeiro vizinho aleatório já for melhor, o algoritmo aceita o movimento imediatamente.
#
# 21. **break**
# > Interrompe a busca local daquela rodada assim que encontra a primeira melhora.
#
# 23. **if not found_better_neighbor:**
# > Se nenhuma melhora aparecer após várias tentativas, o algoritmo considera que ficou preso em um máximo local ou já chegou à solução ideal.
#
# </details>

# %% [markdown]
# ### Hill Climbing com Reinicio Aleatório

# %% [markdown]
# Finalmente, diferente do Hill Climbing puro onde o alpinista que só pode subir. O Hill Climbing com Reinício Aleatório adiciona uma estratégia simples, mas poderosa, para resolver esse problema. Se o algoritmo ficar preso em um máximo local, ele simplesmente "teletransporta" o alpinista para uma nova posição aleatória e começa a busca por um novo pico a partir dali. A ideia é que, ao reiniciar a busca várias vezes a partir de diferentes pontos de partida, a probabilidade de um desses inícios aleatórios levar ao máximo global (a solução ideal) aumenta drasticamente.

# %%
def random_restart_hill_climbing(num_queens, max_restarts=1000):
    """
    Resolve o problema das n rainhas usando Hill Climbing com reinício aleatório.
    Tenta encontrar uma solução com todas as rainhas apaziguadas.
    """
    restarts = 0
    while restarts < max_restarts:
        solution, score = hill_climbing(num_queens)

        if score == num_queens:
            print(f"Success! Solution found in {restarts + 1} attempts.")
            return solution, score

        restarts += 1
        print(f"Attempt {restarts} failed. Restarting...")

    print(f"\nFailure after {max_restarts} attempts.")
    return solution, score

# %% [markdown]
# <details>
# <summary>Por que o Reinício Aleatório aumenta a chance de sucesso sem mudar a lógica local de busca?</summary>
#
# Porque ele não altera o comportamento do Hill Climbing dentro de cada tentativa. A lógica local continua a mesma: subir enquanto houver melhora. O que muda é a **estratégia global**. Em vez de confiar em uma única posição inicial, o algoritmo experimenta vários pontos de partida diferentes. Isso aumenta a probabilidade de que pelo menos uma dessas tentativas comece em uma região mais favorável da paisagem de busca e consiga chegar à solução ideal.
#
# </details>

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def random_restart_hill_climbing(num_queens, max_restarts=1000):**
# > Define a função que gerencia as múltiplas tentativas, aceitando o número de rainhas e um limite de reinícios.
#
# 7. **restarts = 0**
# > Inicializa o contador de quantas vezes o algoritmo precisou começar do zero.
#
# 8. **while restarts < max_restarts:**
# > Mantém o processo rodando enquanto a solução não for encontrada e o limite de tentativas não for atingido.
#
# 9. **solution, score = hill_climbing(num_queens)**
# > Chama a função de busca local. Ela vai subir a "encosta" até onde conseguir e devolver o melhor tabuleiro que encontrou.
#
# 11. **if score == num_queens:**
# > Verifica se a pontuação atingida é o máximo possível (todas as rainhas seguras).
#
# 13. **return solution, score**
# > Se a solução for perfeita, encerra tudo imediatamente e retorna o resultado vitorioso.
#
# 15. **restarts += 1**
# > Caso o Hill Climbing tenha ficado preso em um máximo local (score < num_queens), incrementa o contador de tentativas.
#
# 16. **print(f"Tentativa {restarts} falhou. Reiniciando...")**
# > Avisa ao usuário que aquela "montanha" não era a correta e que uma nova posição aleatória será sorteada.
#
# 19. **return solution, score**
# > Se o loop terminar sem sucesso, retorna a última solução encontrada (a melhor da última tentativa).
#
# </details>

# %% [markdown]
# ### Recozimento Simulado (Simulated Annealing)

# %% [markdown]
# O **Simulated Annealing** (Recozimento Simulado) é uma variante do *Hill Climbing* inspirada no processo metalúrgico de aquecimento e resfriamento gradual. O algoritmo utiliza o conceito de "temperatura" para guiar a busca: no início, com a temperatura alta, ele tem uma alta probabilidade de aceitar "passos ruins" (movimentos que pioram o estado atual). Essa tolerância ao erro funciona como um chacoalhão que permite ao algoritmo escapar de armadilhas e falsos picos (máximos locais). Conforme o processo avança, a temperatura diminui de forma controlada, reduzindo gradativamente a chance de aceitar pioras. Quando o sistema finalmente "esfria", ele passa a se comportar como o *Hill Climbing* tradicional, rejeitando erros e aceitando apenas melhorias até se estabilizar rigidamente na solução ideal (o máximo global).

# %% [markdown]
# Em resumo, a "temperatura" controla a probabilidade de aceitar um movimento que piora a solução.
#
# * **Alta Temperatura:** O algoritmo tem uma alta probabilidade de aceitar um movimento que leva a um estado pior. Isso permite que ele "salte" para fora de máximos/mínimos locais e explore novas áreas da paisagem de busca.
#
# * **Baixa Temperatura:** A probabilidade de aceitar um movimento ruim diminui. O algoritmo começa a se comportar de forma mais parecida com o Hill Climbing, concentrando-se em movimentos que melhoram a solução e se acomodando em um estado de baixa energia (poucos ataques).

# %%
def simulated_annealing(num_queens, initial_temp=100.0, cooling_rate=0.99, verbose=False):
    """Resolve o problema das n rainhas maximizando rainhas apaziguadas."""
    current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]
    current_score = count_peaceful_queens(current_board)
    temperature = initial_temp
    step = 0

    while temperature > 0.001:
        if verbose:
            print(f"Step {step} | Temperature: {temperature:.4f} | Peaceful queens: {current_score}")

        if current_score == num_queens:
            print("Success. Optimal solution was found.")
            return current_board, current_score

        neighbor = list(current_board)
        col_to_move = random.randint(0, num_queens - 1)
        new_row = random.randint(0, num_queens - 1)
        neighbor[col_to_move] = new_row
        neighbor_score = count_peaceful_queens(neighbor)

        delta_score = neighbor_score - current_score

        if delta_score > 0:
            current_board = neighbor
            current_score = neighbor_score
        else:
            probability = math.exp(delta_score / temperature)
            if random.random() < probability:
                current_board = neighbor
                current_score = neighbor_score

        temperature *= cooling_rate
        step += 1

    print("\nThe algorithm has stopped. The final state can be a local or global maximum.")
    return current_board, current_score

# %% [markdown]
# <details>
# <summary>O que significa dizer que o Simulated Annealing equilibra exploração e refinamento?</summary>
#
# Durante a busca, o algoritmo muda seu comportamento ao longo do tempo graças ao parâmetro de **temperatura**. No início, com a temperatura alta, ele atua na fase de **exploração**: aceita com facilidade movimentos piores (quedas na pontuação) para escapar de máximos locais e visitar novas regiões do espaço de busca. Conforme a temperatura cai gradualmente, ele entra na fase de **refinamento**: a tolerância a movimentos ruins diminui exponencialmente e a busca fica mais conservadora, comportando-se cada vez mais como o *Hill Climbing* tradicional, que foca apenas em melhorar a solução atual.
#
# No código, esse equilíbrio dinâmico é perfeitamente ilustrado pelo bloco que calcula a probabilidade e pela atualização da temperatura:
#
# ```python
#         # Se o movimento for ruim (delta_score <= 0), a matemática decide se o aceita
#         else:
#             probability = math.exp(delta_score / temperature)
#             if random.random() < probability:
#                 current_board = neighbor
#                 current_score = neighbor_score
#
#         # O cronograma de resfriamento faz a transição da exploração para o refinamento
#         temperature *= cooling_rate
# ```
#
# Quando a `temperature` é alta o algoritmo esta propenso a exploração. Em termos matematicos, isso faz com que a fração `delta_score / temperature` resulte em uma `probability` muito alta. O sorteio do `random.random()` frequentemente aceita o movimento ruim. Note que a linha `temperature *= cooling_rate` vai esfriando o sistema a cada iteração, i.e., o refinamento. Quando o `temperature` fica muito baixo, a `probability` encolhe para perto de zero, e o `if` passa a rejeitar as jogadas ruins, concentrando-se puramente em subir a encosta rumo à solução final.
#
# A função decrita acima representa a expressão matemática correspondente a **distribuição de Boltzmann**, representada por:
#
# **$e^{\Delta E / T}$**
#
# *   **$e$**: é a base da função exponencial, representada no código por `math.exp`.
# *   **$\Delta E$**: é a variação da pontuação (ou a medida da "ruindade" do movimento), representada no código por `delta_score`.
# *   **$T$**: é a temperatura atual do sistema, representada no código por `temperature`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Explicação</summary>
#
# 1. **def simulated_annealing(num_queens, initial_temp=100.0, cooling_rate=0.99, verbose=False):**
# > Define a função que utiliza uma temperatura inicial, uma taxa de resfriamento e um parâmetro opcional de verbosidade para guiar a busca.
#
# 3. **current_board = [random.randint(0, num_queens - 1) for _ in range(num_queens)]**
# > Começa com um tabuleiro totalmente aleatório.
#
# 6. **step = 0**
# > Cria um contador de iterações para acompanhar a evolução da busca.
#
# 7. **while temperature > 0.001:**
# > O loop principal continua enquanto o sistema ainda tiver "calor" suficiente para realizar mudanças.
#
# 8. **if verbose: print(...)**
# > Quando `verbose=True`, a função mostra a iteração atual, a temperatura e a pontuação do estado, permitindo acompanhar o resfriamento durante a busca.
#
# 9. **if current_score == num_queens:**
# > Se encontrar a solução perfeita (todas as rainhas apaziguadas), interrompe o processo imediatamente.
#
# 12. **neighbor = list(current_board)**
# > Cria um vizinho alterando a posição de apenas uma rainha escolhida aleatoriamente.
#
# 18. **delta_score = neighbor_score - current_score**
# > Calcula a diferença de qualidade. Se for positivo, o vizinho é melhor; se for negativo, o vizinho é pior.
#
# 20. **if delta_score > 0:**
# > Regra de aceitação gananciosa: se o vizinho for melhor, ele é aceito imediatamente.
#
# 24. **else: probability = math.exp(delta_score / temperature)**
# > O "pulo do gato": se o vizinho for pior, calcula-se uma probabilidade de aceitá-lo mesmo assim. Quanto maior a temperatura, mais provável é aceitar erros para explorar o mapa.
#
# 25. **if random.random() < probability:**
# > Decide, através de um sorteio, se vai aceitar a solução pior para tentar escapar de um máximo local.
#
# 29. **temperature \*= cooling_rate**
# > Reduz a temperatura gradualmente. O algoritmo fica cada vez "mais exigente" e menos propenso a aceitar pioras.
#
# 30. **step += 1**
# > Avança o contador de iterações para a próxima rodada da busca.
#
# 33. **return current_board, current_score**
# > Retorna o melhor estado alcançado após o resfriamento completo.
#
# </details>

# %% [markdown]
# ### Visualizar tabuleiro

# %%
# @title Função para gerar tabuleiro
def print_board(board):
    """
    Gera e exibe uma representacao visual do tabuleiro de xadrez como uma imagem.

    Args:
        board (list): Uma lista de 8 posicoes, onde o indice e a coluna
                      e o valor e a linha da rainha.
    """

    import matplotlib.pyplot as plt
    import numpy as np

    n = len(board)
    board_image = np.zeros((n, n, 3), dtype=np.uint8)

    # Define as cores dos quadrados do tabuleiro
    for i in range(n):
        for j in range(n):
            if (i + j) % 2 == 0:
                board_image[i, j] = [255, 255, 255]  # Branco
            else:
                board_image[i, j] = [169, 169, 169]  # Cinza

    plt.imshow(board_image)

    # Desenha as rainhas
    for i in range(n):
        plt.text(i, n - 1 - board[i], '♕', ha='center', va='center', fontsize=20, color='black')

    # Adiciona titulos e rotulos
    plt.title("Tabuleiro de Xadrez com 8 Rainhas")
    plt.xticks(np.arange(n))
    plt.yticks(np.arange(n), labels=np.arange(n-1, -1, -1))
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

# %% [markdown]
# ## Exemplo prático

# %% [markdown]
# ### Cenário 1 - Hill Climbing padrão

# %% [markdown]
# Neste cenário, vamos executar o **Hill Climbing padrão**. O algoritmo começa em um tabuleiro aleatório, avalia todos os vizinhos possíveis em cada passo e sempre escolhe o melhor deles. Se não existir vizinho melhor, a execução para, mesmo que a solução ideal ainda não tenha sido encontrada.

# %%
solution, score = hill_climbing(8)
print("\nFinal Solution:")
print(f"Board: {solution}")
print(f"Peaceful queens: {score}")

if score == 8:
    print("Success! Solution found.")
else:
    print("Failure! Stuck at a local maximum.")
# Out:
# Moving to: [2, 7, 3, 6, 2, 2, 0, 4] | Peaceful queens: 3
# Moving to: [2, 7, 3, 6, 2, 5, 0, 4] | Peaceful queens: 5
# Moving to: [2, 7, 3, 6, 0, 5, 0, 4] | Peaceful queens: 6
# Moving to: [2, 7, 3, 6, 0, 5, 1, 4] | Peaceful queens: 8
#
# Algorithm stopped. Local maximum or solution found.
#
# Final Solution:
# Board: [2, 7, 3, 6, 0, 5, 1, 4]
# Peaceful queens: 8
# Success! Solution found.

# %%
print_board(solution)

# %% [markdown]
# <details>
# <summary>O que observar neste resultado?</summary>
#
# No Hill Climbing padrão, não existe garantia de sucesso em toda execução. Se o algoritmo parar com menos de `8` rainhas apaziguadas, isso significa que ele ficou preso em um **máximo local**. Se chegar a `8`, então encontrou uma solução válida do problema.
#
# </details>

# %% [markdown]
# ### Cenário 2 - Hill Climbing Estocástico

# %% [markdown]
# Agora vamos executar o **Hill Climbing Estocástico**. Diferentemente da versão padrão, ele não escolhe sempre o melhor vizinho. Em cada rodada, ele reúne todos os vizinhos que melhoram o estado atual e sorteia um deles, dando maior chance para as melhorias maiores.

# %%
stochastic_solution, stochastic_score = stochastic_hill_climbing(8)
print("\nFinal Solution:")
print(f"Board: {stochastic_solution}")
print(f"Peaceful queens: {stochastic_score}")

if stochastic_score == 8:
    print("Success! Solution found.")
else:
    print("Failure! Stuck at a local maximum.")
# Out:
# Moving to: [5, 5, 4, 2, 2, 5, 4, 1] | Peaceful queens: 1
# Moving to: [3, 5, 4, 2, 2, 5, 4, 1] | Peaceful queens: 2
# Moving to: [3, 5, 4, 2, 5, 5, 4, 1] | Peaceful queens: 3
# Moving to: [3, 5, 4, 2, 0, 5, 4, 1] | Peaceful queens: 4
# Moving to: [3, 6, 4, 2, 0, 5, 4, 1] | Peaceful queens: 5
# Moving to: [3, 6, 4, 2, 0, 5, 7, 1] | Peaceful queens: 8
#
# Algorithm stopped. Local maximum or solution found.
#
# Final Solution:
# Board: [3, 6, 4, 2, 0, 5, 7, 1]
# Peaceful queens: 8
# Success! Solution found.

# %%
print_board(stochastic_solution)

# %% [markdown]
# ### Cenário 3 - Hill Climbing de Primeira Escolha

# %% [markdown]
# Neste cenário, vamos testar o **Hill Climbing de Primeira Escolha**. Em vez de analisar toda a vizinhança, o algoritmo sorteia movimentos aleatórios e aceita imediatamente o primeiro que melhora a solução atual. Isso torna a execução mais leve, mas também mais dependente do acaso.

# %%
first_choice_solution, first_choice_score = first_choice_hill_climbing(8)
print("\nFinal Solution:")
print(f"Board: {first_choice_solution}")
print(f"Peaceful queens: {first_choice_score}")

if first_choice_score == 8:
    print("Success! Solution found.")
else:
    print("Failure! Stuck at a local maximum.")
# Out:
# Moving to: [6, 0, 2, 7, 5, 0, 7, 4] | Peaceful queens: 3
# Moving to: [6, 0, 2, 7, 5, 7, 7, 4] | Peaceful queens: 4
# Moving to: [6, 0, 2, 7, 5, 7, 1, 4] | Peaceful queens: 6
# Moving to: [6, 0, 2, 7, 5, 3, 1, 4] | Peaceful queens: 8
#
# Algorithm stopped. Local maximum or solution found.
#
# Final Solution:
# Board: [6, 0, 2, 7, 5, 3, 1, 4]
# Peaceful queens: 8
# Success! Solution found.

# %%
print_board(first_choice_solution)

# %% [markdown]
# ### Cenário 4 - Hill Climbing com Reinício Aleatório

# %% [markdown]
# Agora vamos executar o **Hill Climbing com Reinício Aleatório**. A cada tentativa, o algoritmo roda o Hill Climbing padrão a partir de um novo estado inicial aleatório. Se uma execução ficar presa em máximo local, outra tentativa é iniciada até encontrar uma solução ou atingir o número máximo de reinícios.

# %%
final_solution, final_score = random_restart_hill_climbing(32)
print("\nSolucao Final:")
print(f"Tabuleiro: {final_solution}")
print(f"Rainhas apaziguadas: {final_score}")
# Out:
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 0, 4, 2, 7, 10, 12, 25, 14, 20, 8, 14, 21, 26, 11, 11, 30, 3, 28, 5, 22, 25] | Peaceful queens: 7
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 4, 2, 7, 10, 12, 25, 14, 20, 8, 14, 21, 26, 11, 11, 30, 3, 28, 5, 22, 25] | Peaceful queens: 9
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 12, 25, 14, 20, 8, 14, 21, 26, 11, 11, 30, 3, 28, 5, 22, 25] | Peaceful queens: 11
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 12, 25, 14, 20, 8, 14, 21, 26, 11, 11, 24, 3, 28, 5, 22, 25] | Peaceful queens: 14
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 12, 25, 14, 20, 8, 14, 21, 26, 11, 11, 24, 3, 28, 5, 22, 9] | Peaceful queens: 17
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 14, 21, 26, 11, 11, 24, 3, 28, 5, 22, 9] | Peaceful queens: 19
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 12, 21, 26, 11, 11, 24, 3, 28, 5, 22, 9] | Peaceful queens: 22
# Moving to: [4, 30, 16, 10, 1, 6, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 12, 21, 26, 11, 19, 24, 3, 28, 5, 22, 9] | Peaceful queens: 24
# Moving to: [4, 30, 16, 10, 1, 17, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 12, 21, 26, 11, 19, 24, 3, 28, 5, 22, 9] | Peaceful queens: 25
# Moving to: [4, 30, 16, 10, 1, 17, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 12, 21, 26, 11, 19, 24, 3, 28, 10, 22, 9] | Peaceful queens: 26
# Moving to: [4, 30, 16, 5, 1, 17, 31, 13, 18, 10, 15, 27, 29, 2, 7, 10, 0, 25, 14, 20, 8, 12, 21, 26, 11, 19, 24, 3, 28, 10, 22, 9] | Peaceful queens: 27
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 1 failed. Restarting...
# Moving to: [28, 20, 24, 9, 3, 16, 28, 16, 23, 17, 5, 3, 6, 12, 9, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 27, 4, 7, 27, 5] | Peaceful queens: 4
# Moving to: [28, 20, 24, 9, 3, 16, 28, 16, 23, 17, 5, 3, 6, 12, 9, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 0, 4, 7, 27, 5] | Peaceful queens: 7
# Moving to: [28, 20, 24, 9, 3, 16, 2, 16, 23, 17, 5, 3, 6, 12, 9, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 0, 4, 7, 27, 5] | Peaceful queens: 9
# Moving to: [28, 20, 24, 9, 3, 16, 2, 16, 23, 11, 5, 3, 6, 12, 9, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 0, 4, 7, 27, 5] | Peaceful queens: 11
# Moving to: [28, 20, 24, 9, 3, 16, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 0, 4, 7, 27, 5] | Peaceful queens: 13
# Moving to: [28, 20, 24, 9, 3, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 20, 0, 4, 7, 27, 5] | Peaceful queens: 15
# Moving to: [28, 20, 24, 9, 3, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 30, 30, 17, 13, 22, 3, 22, 12, 29, 15, 0, 4, 7, 27, 5] | Peaceful queens: 18
# Moving to: [28, 20, 24, 9, 3, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 25, 30, 17, 13, 22, 3, 22, 12, 29, 15, 0, 4, 7, 27, 5] | Peaceful queens: 20
# Moving to: [28, 20, 24, 9, 3, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 25, 30, 17, 13, 22, 3, 14, 12, 29, 15, 0, 4, 7, 27, 5] | Peaceful queens: 22
# Moving to: [28, 20, 24, 9, 3, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 25, 30, 17, 13, 22, 3, 14, 12, 29, 15, 0, 4, 7, 27, 31] | Peaceful queens: 24
# Moving to: [28, 20, 24, 9, 18, 8, 2, 16, 23, 11, 5, 3, 6, 12, 21, 1, 3, 25, 30, 17, 13, 22, 3, 14, 12, 29, 15, 0, 4, 7, 27, 31] | Peaceful queens: 25
# Moving to: [28, 20, 24, 9, 18, 8, 2, 16, 23, 11, 5, 3, 6, 26, 21, 1, 3, 25, 30, 17, 13, 22, 3, 14, 12, 29, 15, 0, 4, 7, 27, 31] | Peaceful queens: 26
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 2 failed. Restarting...
# Moving to: [5, 2, 8, 26, 27, 28, 29, 19, 18, 18, 13, 17, 31, 4, 28, 8, 20, 7, 17, 1, 9, 15, 0, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 6
# Moving to: [5, 2, 8, 26, 27, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 20, 7, 17, 1, 9, 15, 0, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 9
# Moving to: [5, 2, 8, 11, 27, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 20, 7, 17, 1, 9, 15, 0, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 11
# Moving to: [5, 2, 8, 11, 27, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 0, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 13
# Moving to: [5, 2, 8, 11, 27, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 15
# Moving to: [5, 2, 20, 11, 27, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 16
# Moving to: [5, 2, 20, 11, 0, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 12, 29, 17, 6, 3, 27, 28] | Peaceful queens: 17
# Moving to: [5, 2, 20, 11, 0, 28, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 12, 29, 17, 6, 3, 27, 16] | Peaceful queens: 19
# Moving to: [5, 2, 20, 11, 0, 8, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 12, 29, 17, 6, 3, 27, 16] | Peaceful queens: 20
# Moving to: [5, 2, 20, 11, 0, 8, 29, 19, 30, 18, 13, 17, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 25, 29, 17, 6, 3, 27, 16] | Peaceful queens: 22
# Moving to: [5, 2, 20, 11, 0, 8, 29, 19, 30, 18, 13, 26, 31, 4, 28, 8, 14, 7, 17, 1, 9, 15, 24, 10, 7, 25, 29, 17, 6, 3, 27, 16] | Peaceful queens: 23
# Moving to: [5, 2, 20, 11, 0, 8, 29, 19, 30, 18, 13, 26, 31, 4, 28, 8, 14, 23, 17, 1, 9, 15, 24, 10, 7, 25, 29, 17, 6, 3, 27, 16] | Peaceful queens: 25
# Moving to: [5, 2, 20, 11, 0, 8, 22, 19, 30, 18, 13, 26, 31, 4, 28, 8, 14, 23, 17, 1, 9, 15, 24, 10, 7, 25, 29, 17, 6, 3, 27, 16] | Peaceful queens: 26
# Moving to: [5, 2, 20, 11, 0, 8, 22, 19, 30, 18, 13, 26, 31, 4, 28, 8, 14, 23, 21, 1, 9, 15, 24, 10, 7, 25, 29, 17, 6, 3, 27, 16] | Peaceful queens: 27
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 3 failed. Restarting...
# Moving to: [24, 9, 20, 4, 26, 26, 24, 16, 3, 8, 13, 23, 29, 30, 1, 29, 31, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 5
# Moving to: [24, 9, 20, 4, 26, 26, 2, 16, 3, 8, 13, 23, 29, 30, 1, 29, 31, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 7
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 8, 13, 23, 29, 30, 1, 29, 31, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 9
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 29, 30, 1, 29, 31, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 11
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 31, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 13
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 5, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 15
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 21, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 17
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 22, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 19
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 27, 26, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 21
# Moving to: [24, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 27, 12, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 23
# Moving to: [19, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 27, 12, 22, 0, 8, 3, 28, 15, 24] | Peaceful queens: 24
# Moving to: [19, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 27, 12, 22, 0, 8, 3, 28, 15, 17] | Peaceful queens: 26
# Moving to: [19, 9, 20, 4, 26, 26, 2, 7, 3, 16, 13, 23, 6, 30, 1, 29, 25, 14, 24, 10, 31, 11, 5, 27, 12, 22, 0, 8, 21, 28, 15, 17] | Peaceful queens: 28
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 4 failed. Restarting...
# Moving to: [28, 11, 18, 13, 6, 0, 30, 2, 17, 26, 17, 26, 11, 23, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 5
# Moving to: [28, 11, 18, 13, 6, 0, 30, 7, 17, 26, 17, 26, 11, 23, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 7
# Moving to: [28, 11, 18, 13, 6, 8, 30, 7, 17, 26, 17, 26, 11, 23, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 9
# Moving to: [28, 11, 18, 13, 6, 8, 30, 7, 22, 26, 17, 26, 11, 23, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 11
# Moving to: [28, 11, 18, 13, 6, 8, 30, 7, 22, 26, 17, 26, 5, 23, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 13
# Moving to: [28, 11, 18, 13, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 15
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 13, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 17
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 23, 15, 9, 16, 3, 26, 1, 4, 1, 13, 9, 0, 24, 4, 20, 25, 2] | Peaceful queens: 19
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 23, 15, 9, 16, 3, 26, 1, 4, 1, 13, 29, 0, 24, 4, 20, 25, 2] | Peaceful queens: 21
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 23, 15, 9, 16, 3, 26, 0, 4, 1, 13, 29, 0, 24, 4, 20, 25, 2] | Peaceful queens: 23
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 26, 17, 26, 5, 31, 27, 23, 15, 9, 16, 3, 26, 0, 4, 1, 13, 29, 14, 24, 4, 20, 25, 2] | Peaceful queens: 25
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 10, 17, 26, 5, 31, 27, 23, 15, 9, 16, 3, 26, 0, 4, 1, 13, 29, 14, 24, 4, 20, 25, 2] | Peaceful queens: 26
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 10, 17, 5, 5, 31, 27, 23, 15, 9, 16, 3, 26, 0, 4, 1, 13, 29, 14, 24, 4, 20, 25, 2] | Peaceful queens: 27
# Moving to: [28, 11, 18, 12, 6, 8, 30, 7, 22, 10, 17, 5, 5, 31, 27, 23, 15, 9, 16, 3, 26, 0, 3, 1, 13, 29, 14, 24, 4, 20, 25, 2] | Peaceful queens: 28
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 5 failed. Restarting...
# Moving to: [10, 4, 31, 4, 8, 27, 29, 13, 3, 26, 7, 24, 21, 28, 15, 23, 28, 24, 8, 10, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 8
# Moving to: [10, 4, 31, 4, 8, 27, 2, 13, 3, 26, 7, 24, 21, 28, 15, 23, 28, 24, 8, 10, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 10
# Moving to: [10, 4, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 21, 28, 15, 23, 28, 24, 8, 10, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 12
# Moving to: [10, 4, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 21, 28, 15, 23, 28, 24, 16, 10, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 14
# Moving to: [10, 4, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 21, 28, 15, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 16
# Moving to: [10, 12, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 21, 28, 15, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 17
# Moving to: [10, 12, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 15, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 4, 20, 19] | Peaceful queens: 18
# Moving to: [10, 12, 31, 4, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 15, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 11, 20, 19] | Peaceful queens: 20
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 15, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 11, 20, 19] | Peaceful queens: 21
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 17, 23, 28, 24, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 11, 20, 19] | Peaceful queens: 22
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 17, 23, 28, 30, 16, 6, 1, 28, 22, 0, 29, 5, 15, 28, 22, 11, 20, 19] | Peaceful queens: 23
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 17, 23, 28, 30, 16, 6, 1, 28, 22, 0, 29, 5, 15, 18, 22, 11, 20, 19] | Peaceful queens: 24
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 17, 23, 28, 30, 16, 6, 1, 28, 22, 0, 29, 5, 15, 18, 22, 11, 9, 19] | Peaceful queens: 25
# Moving to: [10, 12, 31, 21, 8, 27, 2, 13, 3, 26, 7, 25, 14, 28, 17, 23, 28, 30, 16, 6, 1, 28, 22, 0, 29, 5, 15, 18, 20, 11, 9, 19] | Peaceful queens: 27
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 6 failed. Restarting...
# Moving to: [21, 28, 30, 19, 14, 16, 1, 14, 13, 23, 20, 10, 28, 9, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 5
# Moving to: [8, 28, 30, 19, 14, 16, 1, 14, 13, 23, 20, 10, 28, 9, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 7
# Moving to: [8, 28, 30, 19, 14, 16, 1, 14, 13, 23, 20, 10, 5, 9, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 9
# Moving to: [8, 28, 30, 19, 14, 16, 1, 14, 13, 23, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 12
# Moving to: [8, 28, 17, 19, 14, 16, 1, 14, 13, 23, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 13
# Moving to: [8, 28, 17, 19, 14, 30, 1, 14, 13, 23, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 15
# Moving to: [8, 28, 17, 19, 22, 30, 1, 14, 13, 23, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 16
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 23, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 17
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 20, 0, 16, 25, 20, 2] | Peaceful queens: 18
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 20, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 12, 0, 16, 25, 20, 2] | Peaceful queens: 20
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 24, 10, 5, 11, 18, 21, 15, 6, 7, 31, 29, 31, 3, 23, 4, 6, 12, 0, 16, 25, 20, 2] | Peaceful queens: 21
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 24, 10, 5, 11, 18, 21, 15, 6, 7, 26, 29, 31, 3, 23, 4, 6, 12, 0, 16, 25, 20, 2] | Peaceful queens: 24
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 24, 3, 5, 11, 18, 21, 15, 6, 7, 26, 29, 31, 3, 23, 4, 6, 12, 0, 16, 25, 20, 2] | Peaceful queens: 25
# Moving to: [8, 28, 17, 19, 22, 30, 1, 9, 13, 3, 24, 3, 5, 11, 18, 21, 27, 6, 7, 26, 29, 31, 3, 23, 4, 6, 12, 0, 16, 25, 20, 2] | Peaceful queens: 26
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 7 failed. Restarting...
# Moving to: [17, 22, 2, 1, 4, 20, 1, 20, 7, 29, 8, 8, 28, 27, 27, 19, 26, 6, 1, 8, 24, 3, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 8
# Moving to: [17, 22, 2, 1, 4, 20, 1, 13, 7, 29, 8, 8, 28, 27, 27, 19, 26, 6, 1, 8, 24, 3, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 10
# Moving to: [17, 22, 2, 1, 4, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 1, 8, 24, 3, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 13
# Moving to: [17, 22, 2, 1, 4, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 1, 8, 10, 3, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 15
# Moving to: [17, 22, 2, 1, 4, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 1, 8, 10, 14, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 17
# Moving to: [17, 22, 2, 1, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 1, 8, 10, 14, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 19
# Moving to: [17, 22, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 1, 8, 10, 14, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 21
# Moving to: [17, 22, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 30, 8, 10, 14, 4, 0, 31, 11, 5, 12, 9, 3, 15, 8] | Peaceful queens: 23
# Moving to: [17, 22, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 30, 8, 10, 14, 4, 0, 31, 11, 5, 23, 9, 3, 15, 8] | Peaceful queens: 25
# Moving to: [17, 12, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 30, 8, 10, 14, 4, 0, 31, 11, 5, 23, 9, 3, 15, 8] | Peaceful queens: 26
# Moving to: [17, 12, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 30, 24, 10, 14, 4, 0, 31, 11, 5, 23, 9, 3, 15, 8] | Peaceful queens: 27
# Moving to: [17, 12, 2, 21, 18, 20, 1, 13, 7, 29, 8, 8, 28, 16, 27, 19, 26, 6, 30, 24, 10, 14, 4, 0, 31, 11, 5, 23, 9, 3, 15, 22] | Peaceful queens: 28
# Moving to: [17, 12, 2, 21, 18, 20, 1, 13, 7, 29, 8, 0, 28, 16, 27, 19, 26, 6, 30, 24, 10, 14, 4, 0, 31, 11, 5, 23, 9, 3, 15, 22] | Peaceful queens: 29
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 8 failed. Restarting...
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 9, 8, 25, 26, 20, 13, 7, 4, 3, 9, 18, 16, 2, 14, 14, 29, 2, 5, 23, 28, 20, 27] | Peaceful queens: 5
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 3, 9, 18, 16, 2, 14, 14, 29, 2, 5, 23, 28, 20, 27] | Peaceful queens: 7
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 0, 9, 18, 16, 2, 14, 14, 29, 2, 5, 23, 28, 20, 27] | Peaceful queens: 9
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 14, 14, 29, 2, 5, 23, 28, 20, 27] | Peaceful queens: 11
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 14, 14, 29, 19, 5, 23, 28, 20, 27] | Peaceful queens: 13
# Moving to: [1, 26, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 14, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 15
# Moving to: [1, 11, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 25, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 14, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 16
# Moving to: [1, 11, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 14, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 18
# Moving to: [1, 11, 20, 3, 21, 16, 15, 6, 14, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 21
# Moving to: [1, 11, 24, 3, 21, 16, 15, 6, 14, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 22
# Moving to: [1, 11, 24, 3, 21, 31, 15, 6, 14, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 23
# Moving to: [1, 11, 24, 3, 21, 31, 9, 6, 14, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 24
# Moving to: [1, 11, 24, 3, 21, 31, 9, 6, 22, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 20, 27] | Peaceful queens: 25
# Moving to: [1, 11, 24, 3, 21, 31, 9, 6, 22, 28, 30, 8, 17, 26, 20, 13, 7, 4, 0, 9, 18, 10, 2, 25, 14, 29, 19, 5, 23, 12, 16, 27] | Peaceful queens: 27
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 9 failed. Restarting...
# Moving to: [6, 8, 22, 14, 29, 4, 11, 22, 15, 31, 4, 0, 14, 14, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 14, 22, 0, 29] | Peaceful queens: 5
# Moving to: [6, 8, 22, 14, 29, 4, 11, 22, 15, 31, 4, 0, 14, 14, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 8
# Moving to: [6, 17, 22, 14, 29, 4, 11, 22, 15, 31, 4, 0, 14, 14, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 10
# Moving to: [6, 17, 22, 14, 1, 4, 11, 22, 15, 31, 4, 0, 14, 14, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 12
# Moving to: [6, 17, 22, 14, 1, 30, 11, 22, 15, 31, 4, 0, 14, 14, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 14
# Moving to: [6, 17, 22, 14, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 16
# Moving to: [6, 17, 22, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 5, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 18
# Moving to: [6, 17, 22, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 31, 7, 11, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 20
# Moving to: [6, 17, 22, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 31, 7, 5, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 22
# Moving to: [6, 17, 20, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 31, 7, 5, 8, 0, 0, 27, 18, 9, 22, 0, 29] | Peaceful queens: 23
# Moving to: [6, 17, 20, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 31, 7, 5, 8, 0, 0, 27, 18, 9, 28, 0, 29] | Peaceful queens: 25
# Moving to: [6, 17, 20, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 13, 7, 5, 8, 0, 0, 27, 18, 9, 28, 0, 29] | Peaceful queens: 26
# Moving to: [6, 17, 20, 12, 1, 30, 11, 22, 15, 31, 4, 0, 14, 3, 24, 19, 16, 25, 2, 31, 13, 7, 5, 8, 0, 21, 27, 18, 9, 28, 0, 29] | Peaceful queens: 27
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 10 failed. Restarting...
# Moving to: [16, 15, 30, 22, 0, 16, 30, 23, 24, 7, 4, 26, 26, 31, 11, 24, 19, 28, 26, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 8
# Moving to: [16, 15, 30, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 28, 26, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 10
# Moving to: [16, 15, 30, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 26, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 12
# Moving to: [10, 15, 30, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 26, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 14
# Moving to: [10, 15, 30, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 16
# Moving to: [10, 8, 30, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 17
# Moving to: [10, 8, 15, 22, 0, 16, 30, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 18
# Moving to: [10, 8, 15, 22, 0, 16, 28, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 20
# Moving to: [10, 8, 15, 9, 0, 16, 28, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 25, 14, 1, 22, 2] | Peaceful queens: 21
# Moving to: [10, 8, 15, 9, 0, 16, 28, 12, 24, 7, 4, 26, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 27, 14, 1, 22, 2] | Peaceful queens: 23
# Moving to: [10, 8, 15, 9, 0, 16, 28, 12, 24, 7, 4, 13, 26, 31, 11, 24, 19, 29, 5, 3, 18, 11, 23, 6, 17, 24, 30, 27, 14, 1, 22, 2] | Peaceful queens: 24
# Moving to: [10, 8, 15, 9, 0, 16, 28, 12, 24, 7, 4, 13, 26, 31, 11, 24, 19, 29, 5, 3, 11, 11, 23, 6, 17, 24, 30, 27, 14, 1, 22, 2] | Peaceful queens: 26
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 11 failed. Restarting...
# Moving to: [18, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 23, 29, 20, 0, 27, 4, 9, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 4
# Moving to: [18, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 23, 29, 20, 0, 27, 3, 9, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 7
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 23, 29, 20, 0, 27, 3, 9, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 10
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 24, 29, 20, 0, 27, 3, 9, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 12
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 24, 29, 31, 0, 27, 3, 9, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 14
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 20, 16, 10, 22, 25, 29, 28] | Peaceful queens: 16
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 20, 6, 10, 22, 25, 29, 28] | Peaceful queens: 18
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 2, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 20, 6, 10, 22, 25, 5, 28] | Peaceful queens: 20
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 26, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 20, 6, 10, 22, 25, 5, 28] | Peaceful queens: 22
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 26, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 20, 6, 10, 22, 25, 5, 21] | Peaceful queens: 24
# Moving to: [1, 16, 28, 2, 14, 7, 23, 18, 15, 12, 17, 4, 26, 9, 9, 13, 24, 29, 31, 0, 27, 3, 11, 8, 20, 30, 6, 10, 22, 25, 5, 21] | Peaceful queens: 25
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 12 failed. Restarting...
# Moving to: [21, 9, 27, 27, 28, 4, 21, 12, 12, 22, 5, 0, 26, 1, 14, 20, 4, 4, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 29, 27] | Peaceful queens: 8
# Moving to: [21, 9, 27, 27, 28, 4, 18, 12, 12, 22, 5, 0, 26, 1, 14, 20, 4, 4, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 29, 27] | Peaceful queens: 10
# Moving to: [21, 9, 27, 27, 28, 4, 18, 12, 12, 22, 5, 0, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 29, 27] | Peaceful queens: 12
# Moving to: [21, 9, 27, 27, 28, 4, 18, 12, 12, 22, 3, 0, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 29, 27] | Peaceful queens: 14
# Moving to: [21, 9, 27, 27, 28, 4, 18, 12, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 29, 27] | Peaceful queens: 16
# Moving to: [21, 9, 27, 27, 28, 4, 18, 12, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 18
# Moving to: [21, 9, 24, 27, 28, 4, 18, 12, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 19
# Moving to: [21, 9, 24, 27, 28, 4, 18, 1, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 20
# Moving to: [21, 9, 24, 27, 15, 4, 18, 1, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 28, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 21
# Moving to: [21, 9, 24, 27, 15, 4, 18, 1, 12, 22, 3, 6, 26, 1, 14, 20, 4, 19, 5, 28, 30, 11, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 23
# Moving to: [21, 9, 24, 27, 15, 4, 18, 1, 12, 22, 3, 6, 26, 1, 14, 20, 23, 19, 5, 28, 30, 11, 0, 29, 10, 2, 7, 31, 1, 8, 13, 27] | Peaceful queens: 25
# Moving to: [21, 9, 24, 27, 15, 4, 18, 1, 12, 22, 3, 6, 26, 1, 14, 20, 23, 19, 5, 28, 30, 11, 0, 29, 10, 2, 7, 31, 17, 8, 13, 27] | Peaceful queens: 26
# Moving to: [21, 9, 24, 27, 15, 4, 18, 1, 12, 22, 3, 6, 26, 16, 14, 20, 23, 19, 5, 28, 30, 11, 0, 29, 10, 2, 7, 31, 17, 8, 13, 27] | Peaceful queens: 28
#
# Algorithm stopped. Local maximum or solution found.
# Attempt 13 failed. Restarting...
# Moving to: [26, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 1, 21, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 15, 8, 26, 17, 19] | Peaceful queens: 6
# Moving to: [26, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 1, 21, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 15, 8, 26, 14, 19] | Peaceful queens: 9
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 1, 21, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 15, 8, 26, 14, 19] | Peaceful queens: 11
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 21, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 15, 8, 26, 14, 19] | Peaceful queens: 13
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 15, 8, 26, 14, 19] | Peaceful queens: 15
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 19, 3, 18, 31, 5, 13, 6, 8, 26, 14, 19] | Peaceful queens: 17
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 31, 5, 13, 6, 8, 26, 14, 19] | Peaceful queens: 19
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 31, 5, 13, 6, 8, 30, 14, 19] | Peaceful queens: 21
# Moving to: [12, 3, 7, 29, 1, 25, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 31, 5, 13, 6, 26, 30, 14, 19] | Peaceful queens: 23
# Moving to: [12, 3, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 31, 5, 13, 6, 26, 30, 14, 19] | Peaceful queens: 24
# Moving to: [12, 3, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 24, 5, 13, 6, 26, 30, 14, 19] | Peaceful queens: 26
# Moving to: [12, 25, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 3, 18, 24, 5, 13, 6, 26, 30, 14, 19] | Peaceful queens: 27
# Moving to: [12, 25, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 21, 18, 24, 5, 13, 6, 26, 30, 14, 19] | Peaceful queens: 29
# Moving to: [12, 25, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 2, 4, 23, 9, 22, 3, 11, 15, 5, 10, 21, 18, 24, 2, 13, 6, 26, 30, 14, 19] | Peaceful queens: 30
# Moving to: [12, 25, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 16, 4, 23, 9, 22, 3, 11, 15, 5, 10, 21, 18, 24, 2, 13, 6, 26, 30, 14, 19] | Peaceful queens: 32
#
# Algorithm stopped. Local maximum or solution found.
# Success! Solution found in 14 attempts.
#
# Solucao Final:
# Tabuleiro: [12, 25, 7, 29, 1, 8, 17, 28, 0, 27, 20, 31, 16, 4, 23, 9, 22, 3, 11, 15, 5, 10, 21, 18, 24, 2, 13, 6, 26, 30, 14, 19]
# Rainhas apaziguadas: 32

# %%
print_board(final_solution)

# %% [markdown]
# ### Cenário 5 - Simulated Annealing

# %% [markdown]
# Por fim, vamos executar o **Simulated Annealing** em seu modo normal. Esse algoritmo começa em um estado aleatório e pode aceitar movimentos que pioram temporariamente a solução. Conforme a temperatura diminui, a busca fica mais conservadora e passa a refinar a melhor região encontrada.

# %%
annealing_solution, annealing_score = simulated_annealing(8)
print("\nFinal Solution:")
print(f"Board configuration: {annealing_solution}")
print(f"Peaceful queens: {annealing_score}")
# Out:
# Success. Optimal solution was found.
#
# Final Solution:
# Board configuration: [0, 6, 4, 7, 1, 3, 5, 2]
# Peaceful queens: 8

# %%
print_board(annealing_solution)

# %% [markdown]
# <details>
# <summary>O que observar neste resultado?</summary>
#
# No Simulated Annealing, a solução pode melhorar mesmo depois de aceitar alguns movimentos piores ao longo do caminho. Isso acontece porque o algoritmo usa a temperatura para equilibrar exploração e refinamento. Se chegar a `8`, encontrou uma solução válida; se parar antes disso, terminou o processo de resfriamento sem alcançar o ótimo global.
#
# </details>

# %% [markdown]
# ### Cenário 6 - Simulated Annealing com verbose

# %% [markdown]
# Neste cenário, vamos executar novamente o **Simulated Annealing**, mas agora com `verbose=True`. Assim, além do resultado final, será possível acompanhar a temperatura diminuindo durante a busca e observar como o algoritmo vai ficando menos exploratório a cada iteração.

# %%
verbose_solution, verbose_score = simulated_annealing(8, verbose=True)
print("\nFinal Solution:")
print(f"Board configuration: {verbose_solution}")
print(f"Peaceful queens: {verbose_score}")
# Out:
# Step 0 | Temperature: 100.0000 | Peaceful queens: 1
# Step 1 | Temperature: 99.0000 | Peaceful queens: 1
# Step 2 | Temperature: 98.0100 | Peaceful queens: 2
# Step 3 | Temperature: 97.0299 | Peaceful queens: 0
# Step 4 | Temperature: 96.0596 | Peaceful queens: 0
# Step 5 | Temperature: 95.0990 | Peaceful queens: 2
# Step 6 | Temperature: 94.1480 | Peaceful queens: 1
# Step 7 | Temperature: 93.2065 | Peaceful queens: 2
# Step 8 | Temperature: 92.2745 | Peaceful queens: 2
# Step 9 | Temperature: 91.3517 | Peaceful queens: 0
# Step 10 | Temperature: 90.4382 | Peaceful queens: 0
# Step 11 | Temperature: 89.5338 | Peaceful queens: 0
# Step 12 | Temperature: 88.6385 | Peaceful queens: 0
# Step 13 | Temperature: 87.7521 | Peaceful queens: 1
# Step 14 | Temperature: 86.8746 | Peaceful queens: 1
# Step 15 | Temperature: 86.0058 | Peaceful queens: 4
# Step 16 | Temperature: 85.1458 | Peaceful queens: 2
# Step 17 | Temperature: 84.2943 | Peaceful queens: 2
# Step 18 | Temperature: 83.4514 | Peaceful queens: 1
# Step 19 | Temperature: 82.6169 | Peaceful queens: 0
# Step 20 | Temperature: 81.7907 | Peaceful queens: 1
# Step 21 | Temperature: 80.9728 | Peaceful queens: 1
# Step 22 | Temperature: 80.1631 | Peaceful queens: 1
# Step 23 | Temperature: 79.3614 | Peaceful queens: 0
# Step 24 | Temperature: 78.5678 | Peaceful queens: 1
# Step 25 | Temperature: 77.7821 | Peaceful queens: 1
# Step 26 | Temperature: 77.0043 | Peaceful queens: 1
# Step 27 | Temperature: 76.2343 | Peaceful queens: 2
# Step 28 | Temperature: 75.4719 | Peaceful queens: 2
# Step 29 | Temperature: 74.7172 | Peaceful queens: 1
# Step 30 | Temperature: 73.9700 | Peaceful queens: 0
# Step 31 | Temperature: 73.2303 | Peaceful queens: 0
# Step 32 | Temperature: 72.4980 | Peaceful queens: 0
# Step 33 | Temperature: 71.7731 | Peaceful queens: 1
# Step 34 | Temperature: 71.0553 | Peaceful queens: 1
# Step 35 | Temperature: 70.3448 | Peaceful queens: 2
# Step 36 | Temperature: 69.6413 | Peaceful queens: 1
# Step 37 | Temperature: 68.9449 | Peaceful queens: 0
# Step 38 | Temperature: 68.2555 | Peaceful queens: 0
# Step 39 | Temperature: 67.5729 | Peaceful queens: 0
# Step 40 | Temperature: 66.8972 | Peaceful queens: 0
# Step 41 | Temperature: 66.2282 | Peaceful queens: 0
# Step 42 | Temperature: 65.5659 | Peaceful queens: 0
# Step 43 | Temperature: 64.9103 | Peaceful queens: 1
# Step 44 | Temperature: 64.2612 | Peaceful queens: 0
# Step 45 | Temperature: 63.6185 | Peaceful queens: 0
# Step 46 | Temperature: 62.9824 | Peaceful queens: 1
# Step 47 | Temperature: 62.3525 | Peaceful queens: 1
# Step 48 | Temperature: 61.7290 | Peaceful queens: 1
# Step 49 | Temperature: 61.1117 | Peaceful queens: 1
# Step 50 | Temperature: 60.5006 | Peaceful queens: 2
# Step 51 | Temperature: 59.8956 | Peaceful queens: 1
# Step 52 | Temperature: 59.2966 | Peaceful queens: 2
# Step 53 | Temperature: 58.7037 | Peaceful queens: 1
# Step 54 | Temperature: 58.1166 | Peaceful queens: 1
# Step 55 | Temperature: 57.5355 | Peaceful queens: 0
# Step 56 | Temperature: 56.9601 | Peaceful queens: 0
# Step 57 | Temperature: 56.3905 | Peaceful queens: 0
# Step 58 | Temperature: 55.8266 | Peaceful queens: 1
# Step 59 | Temperature: 55.2683 | Peaceful queens: 1
# Step 60 | Temperature: 54.7157 | Peaceful queens: 1
# Step 61 | Temperature: 54.1685 | Peaceful queens: 1
# Step 62 | Temperature: 53.6268 | Peaceful queens: 1
# Step 63 | Temperature: 53.0906 | Peaceful queens: 1
# Step 64 | Temperature: 52.5596 | Peaceful queens: 1
# Step 65 | Temperature: 52.0341 | Peaceful queens: 1
# Step 66 | Temperature: 51.5137 | Peaceful queens: 1
# Step 67 | Temperature: 50.9986 | Peaceful queens: 2
# Step 68 | Temperature: 50.4886 | Peaceful queens: 0
# Step 69 | Temperature: 49.9837 | Peaceful queens: 0
# Step 70 | Temperature: 49.4839 | Peaceful queens: 1
# Step 71 | Temperature: 48.9890 | Peaceful queens: 0
# Step 72 | Temperature: 48.4991 | Peaceful queens: 0
# Step 73 | Temperature: 48.0141 | Peaceful queens: 0
# Step 74 | Temperature: 47.5340 | Peaceful queens: 0
# Step 75 | Temperature: 47.0587 | Peaceful queens: 0
# Step 76 | Temperature: 46.5881 | Peaceful queens: 0
# Step 77 | Temperature: 46.1222 | Peaceful queens: 0
# Step 78 | Temperature: 45.6610 | Peaceful queens: 1
# Step 79 | Temperature: 45.2044 | Peaceful queens: 1
# Step 80 | Temperature: 44.7523 | Peaceful queens: 0
# Step 81 | Temperature: 44.3048 | Peaceful queens: 1
# Step 82 | Temperature: 43.8618 | Peaceful queens: 1
# Step 83 | Temperature: 43.4231 | Peaceful queens: 2
# Step 84 | Temperature: 42.9889 | Peaceful queens: 0
# Step 85 | Temperature: 42.5590 | Peaceful queens: 1
# Step 86 | Temperature: 42.1334 | Peaceful queens: 1
# Step 87 | Temperature: 41.7121 | Peaceful queens: 1
# Step 88 | Temperature: 41.2950 | Peaceful queens: 1
# Step 89 | Temperature: 40.8820 | Peaceful queens: 0
# Step 90 | Temperature: 40.4732 | Peaceful queens: 0
# Step 91 | Temperature: 40.0685 | Peaceful queens: 0
# Step 92 | Temperature: 39.6678 | Peaceful queens: 0
# Step 93 | Temperature: 39.2711 | Peaceful queens: 1
# Step 94 | Temperature: 38.8784 | Peaceful queens: 1
# Step 95 | Temperature: 38.4896 | Peaceful queens: 3
# Step 96 | Temperature: 38.1047 | Peaceful queens: 2
# Step 97 | Temperature: 37.7237 | Peaceful queens: 3
# Step 98 | Temperature: 37.3464 | Peaceful queens: 3
# Step 99 | Temperature: 36.9730 | Peaceful queens: 2
# Step 100 | Temperature: 36.6032 | Peaceful queens: 2
# Step 101 | Temperature: 36.2372 | Peaceful queens: 2
# Step 102 | Temperature: 35.8748 | Peaceful queens: 3
# Step 103 | Temperature: 35.5161 | Peaceful queens: 2
# Step 104 | Temperature: 35.1609 | Peaceful queens: 1
# Step 105 | Temperature: 34.8093 | Peaceful queens: 1
# Step 106 | Temperature: 34.4612 | Peaceful queens: 1
# Step 107 | Temperature: 34.1166 | Peaceful queens: 1
# Step 108 | Temperature: 33.7754 | Peaceful queens: 2
# Step 109 | Temperature: 33.4377 | Peaceful queens: 1
# Step 110 | Temperature: 33.1033 | Peaceful queens: 2
# Step 111 | Temperature: 32.7723 | Peaceful queens: 1
# Step 112 | Temperature: 32.4446 | Peaceful queens: 2
# Step 113 | Temperature: 32.1201 | Peaceful queens: 1
# Step 114 | Temperature: 31.7989 | Peaceful queens: 1
# Step 115 | Temperature: 31.4809 | Peaceful queens: 1
# Step 116 | Temperature: 31.1661 | Peaceful queens: 1
# Step 117 | Temperature: 30.8544 | Peaceful queens: 2
# Step 118 | Temperature: 30.5459 | Peaceful queens: 2
# Step 119 | Temperature: 30.2404 | Peaceful queens: 0
# Step 120 | Temperature: 29.9380 | Peaceful queens: 0
# Step 121 | Temperature: 29.6387 | Peaceful queens: 0
# Step 122 | Temperature: 29.3423 | Peaceful queens: 1
# Step 123 | Temperature: 29.0488 | Peaceful queens: 1
# Step 124 | Temperature: 28.7584 | Peaceful queens: 1
# Step 125 | Temperature: 28.4708 | Peaceful queens: 1
# Step 126 | Temperature: 28.1861 | Peaceful queens: 2
# Step 127 | Temperature: 27.9042 | Peaceful queens: 2
# Step 128 | Temperature: 27.6252 | Peaceful queens: 1
# Step 129 | Temperature: 27.3489 | Peaceful queens: 0
# Step 130 | Temperature: 27.0754 | Peaceful queens: 1
# Step 131 | Temperature: 26.8047 | Peaceful queens: 1
# Step 132 | Temperature: 26.5366 | Peaceful queens: 1
# Step 133 | Temperature: 26.2713 | Peaceful queens: 2
# Step 134 | Temperature: 26.0085 | Peaceful queens: 2
# Step 135 | Temperature: 25.7485 | Peaceful queens: 2
# Step 136 | Temperature: 25.4910 | Peaceful queens: 1
# Step 137 | Temperature: 25.2361 | Peaceful queens: 0
# Step 138 | Temperature: 24.9837 | Peaceful queens: 0
# Step 139 | Temperature: 24.7339 | Peaceful queens: 0
# Step 140 | Temperature: 24.4865 | Peaceful queens: 0
# Step 141 | Temperature: 24.2417 | Peaceful queens: 0
# Step 142 | Temperature: 23.9992 | Peaceful queens: 0
# Step 143 | Temperature: 23.7593 | Peaceful queens: 0
# Step 144 | Temperature: 23.5217 | Peaceful queens: 0
# Step 145 | Temperature: 23.2864 | Peaceful queens: 0
# Step 146 | Temperature: 23.0536 | Peaceful queens: 0
# Step 147 | Temperature: 22.8230 | Peaceful queens: 0
# Step 148 | Temperature: 22.5948 | Peaceful queens: 0
# Step 149 | Temperature: 22.3689 | Peaceful queens: 2
# Step 150 | Temperature: 22.1452 | Peaceful queens: 3
# Step 151 | Temperature: 21.9237 | Peaceful queens: 2
# Step 152 | Temperature: 21.7045 | Peaceful queens: 1
# Step 153 | Temperature: 21.4874 | Peaceful queens: 0
# Step 154 | Temperature: 21.2726 | Peaceful queens: 0
# Step 155 | Temperature: 21.0598 | Peaceful queens: 0
# Step 156 | Temperature: 20.8492 | Peaceful queens: 0
# Step 157 | Temperature: 20.6408 | Peaceful queens: 1
# Step 158 | Temperature: 20.4343 | Peaceful queens: 0
# Step 159 | Temperature: 20.2300 | Peaceful queens: 0
# Step 160 | Temperature: 20.0277 | Peaceful queens: 0
# Step 161 | Temperature: 19.8274 | Peaceful queens: 0
# Step 162 | Temperature: 19.6292 | Peaceful queens: 0
# Step 163 | Temperature: 19.4329 | Peaceful queens: 0
# Step 164 | Temperature: 19.2385 | Peaceful queens: 0
# Step 165 | Temperature: 19.0461 | Peaceful queens: 0
# Step 166 | Temperature: 18.8557 | Peaceful queens: 0
# Step 167 | Temperature: 18.6671 | Peaceful queens: 0
# Step 168 | Temperature: 18.4805 | Peaceful queens: 0
# Step 169 | Temperature: 18.2957 | Peaceful queens: 0
# Step 170 | Temperature: 18.1127 | Peaceful queens: 0
# Step 171 | Temperature: 17.9316 | Peaceful queens: 0
# Step 172 | Temperature: 17.7523 | Peaceful queens: 0
# Step 173 | Temperature: 17.5747 | Peaceful queens: 1
# Step 174 | Temperature: 17.3990 | Peaceful queens: 1
# Step 175 | Temperature: 17.2250 | Peaceful queens: 1
# Step 176 | Temperature: 17.0527 | Peaceful queens: 1
# Step 177 | Temperature: 16.8822 | Peaceful queens: 1
# Step 178 | Temperature: 16.7134 | Peaceful queens: 1
# Step 179 | Temperature: 16.5463 | Peaceful queens: 0
# Step 180 | Temperature: 16.3808 | Peaceful queens: 2
# Step 181 | Temperature: 16.2170 | Peaceful queens: 2
# Step 182 | Temperature: 16.0548 | Peaceful queens: 2
# Step 183 | Temperature: 15.8943 | Peaceful queens: 2
# Step 184 | Temperature: 15.7353 | Peaceful queens: 2
# Step 185 | Temperature: 15.5780 | Peaceful queens: 2
# Step 186 | Temperature: 15.4222 | Peaceful queens: 1
# Step 187 | Temperature: 15.2680 | Peaceful queens: 1
# Step 188 | Temperature: 15.1153 | Peaceful queens: 1
# Step 189 | Temperature: 14.9641 | Peaceful queens: 0
# Step 190 | Temperature: 14.8145 | Peaceful queens: 0
# Step 191 | Temperature: 14.6664 | Peaceful queens: 1
# Step 192 | Temperature: 14.5197 | Peaceful queens: 0
# Step 193 | Temperature: 14.3745 | Peaceful queens: 0
# Step 194 | Temperature: 14.2307 | Peaceful queens: 0
# Step 195 | Temperature: 14.0884 | Peaceful queens: 1
# Step 196 | Temperature: 13.9476 | Peaceful queens: 1
# Step 197 | Temperature: 13.8081 | Peaceful queens: 1
# Step 198 | Temperature: 13.6700 | Peaceful queens: 0
# Step 199 | Temperature: 13.5333 | Peaceful queens: 0
# Step 200 | Temperature: 13.3980 | Peaceful queens: 0
# Step 201 | Temperature: 13.2640 | Peaceful queens: 0
# Step 202 | Temperature: 13.1313 | Peaceful queens: 0
# Step 203 | Temperature: 13.0000 | Peaceful queens: 1
# Step 204 | Temperature: 12.8700 | Peaceful queens: 2
# Step 205 | Temperature: 12.7413 | Peaceful queens: 1
# Step 206 | Temperature: 12.6139 | Peaceful queens: 2
# Step 207 | Temperature: 12.4878 | Peaceful queens: 2
# Step 208 | Temperature: 12.3629 | Peaceful queens: 4
# Step 209 | Temperature: 12.2393 | Peaceful queens: 3
# Step 210 | Temperature: 12.1169 | Peaceful queens: 2
# Step 211 | Temperature: 11.9957 | Peaceful queens: 1
# Step 212 | Temperature: 11.8758 | Peaceful queens: 1
# Step 213 | Temperature: 11.7570 | Peaceful queens: 1
# Step 214 | Temperature: 11.6394 | Peaceful queens: 1
# Step 215 | Temperature: 11.5230 | Peaceful queens: 1
# Step 216 | Temperature: 11.4078 | Peaceful queens: 1
# Step 217 | Temperature: 11.2937 | Peaceful queens: 0
# Step 218 | Temperature: 11.1808 | Peaceful queens: 0
# Step 219 | Temperature: 11.0690 | Peaceful queens: 2
# Step 220 | Temperature: 10.9583 | Peaceful queens: 1
# Step 221 | Temperature: 10.8487 | Peaceful queens: 0
# Step 222 | Temperature: 10.7402 | Peaceful queens: 0
# Step 223 | Temperature: 10.6328 | Peaceful queens: 1
# Step 224 | Temperature: 10.5265 | Peaceful queens: 1
# Step 225 | Temperature: 10.4212 | Peaceful queens: 0
# Step 226 | Temperature: 10.3170 | Peaceful queens: 0
# Step 227 | Temperature: 10.2138 | Peaceful queens: 0
# Step 228 | Temperature: 10.1117 | Peaceful queens: 1
# Step 229 | Temperature: 10.0106 | Peaceful queens: 1
# Step 230 | Temperature: 9.9105 | Peaceful queens: 1
# Step 231 | Temperature: 9.8114 | Peaceful queens: 0
# Step 232 | Temperature: 9.7133 | Peaceful queens: 0
# Step 233 | Temperature: 9.6161 | Peaceful queens: 1
# Step 234 | Temperature: 9.5200 | Peaceful queens: 1
# Step 235 | Temperature: 9.4248 | Peaceful queens: 1
# Step 236 | Temperature: 9.3305 | Peaceful queens: 0
# Step 237 | Temperature: 9.2372 | Peaceful queens: 0
# Step 238 | Temperature: 9.1448 | Peaceful queens: 0
# Step 239 | Temperature: 9.0534 | Peaceful queens: 0
# Step 240 | Temperature: 8.9629 | Peaceful queens: 0
# Step 241 | Temperature: 8.8732 | Peaceful queens: 0
# Step 242 | Temperature: 8.7845 | Peaceful queens: 0
# Step 243 | Temperature: 8.6967 | Peaceful queens: 0
# Step 244 | Temperature: 8.6097 | Peaceful queens: 0
# Step 245 | Temperature: 8.5236 | Peaceful queens: 2
# Step 246 | Temperature: 8.4384 | Peaceful queens: 0
# Step 247 | Temperature: 8.3540 | Peaceful queens: 0
# Step 248 | Temperature: 8.2704 | Peaceful queens: 0
# Step 249 | Temperature: 8.1877 | Peaceful queens: 1
# Step 250 | Temperature: 8.1059 | Peaceful queens: 2
# Step 251 | Temperature: 8.0248 | Peaceful queens: 2
# Step 252 | Temperature: 7.9445 | Peaceful queens: 2
# Step 253 | Temperature: 7.8651 | Peaceful queens: 2
# Step 254 | Temperature: 7.7864 | Peaceful queens: 1
# Step 255 | Temperature: 7.7086 | Peaceful queens: 1
# Step 256 | Temperature: 7.6315 | Peaceful queens: 1
# Step 257 | Temperature: 7.5552 | Peaceful queens: 1
# Step 258 | Temperature: 7.4796 | Peaceful queens: 1
# Step 259 | Temperature: 7.4048 | Peaceful queens: 2
# Step 260 | Temperature: 7.3308 | Peaceful queens: 2
# Step 261 | Temperature: 7.2575 | Peaceful queens: 1
# Step 262 | Temperature: 7.1849 | Peaceful queens: 1
# Step 263 | Temperature: 7.1131 | Peaceful queens: 1
# Step 264 | Temperature: 7.0419 | Peaceful queens: 1
# Step 265 | Temperature: 6.9715 | Peaceful queens: 1
# Step 266 | Temperature: 6.9018 | Peaceful queens: 1
# Step 267 | Temperature: 6.8328 | Peaceful queens: 3
# Step 268 | Temperature: 6.7644 | Peaceful queens: 4
# Step 269 | Temperature: 6.6968 | Peaceful queens: 3
# Step 270 | Temperature: 6.6298 | Peaceful queens: 2
# Step 271 | Temperature: 6.5635 | Peaceful queens: 2
# Step 272 | Temperature: 6.4979 | Peaceful queens: 2
# Step 273 | Temperature: 6.4329 | Peaceful queens: 2
# Step 274 | Temperature: 6.3686 | Peaceful queens: 2
# Step 275 | Temperature: 6.3049 | Peaceful queens: 2
# Step 276 | Temperature: 6.2419 | Peaceful queens: 2
# Step 277 | Temperature: 6.1794 | Peaceful queens: 2
# Step 278 | Temperature: 6.1176 | Peaceful queens: 2
# Step 279 | Temperature: 6.0565 | Peaceful queens: 2
# Step 280 | Temperature: 5.9959 | Peaceful queens: 0
# Step 281 | Temperature: 5.9359 | Peaceful queens: 0
# Step 282 | Temperature: 5.8766 | Peaceful queens: 0
# Step 283 | Temperature: 5.8178 | Peaceful queens: 1
# Step 284 | Temperature: 5.7596 | Peaceful queens: 1
# Step 285 | Temperature: 5.7020 | Peaceful queens: 0
# Step 286 | Temperature: 5.6450 | Peaceful queens: 0
# Step 287 | Temperature: 5.5886 | Peaceful queens: 0
# Step 288 | Temperature: 5.5327 | Peaceful queens: 0
# Step 289 | Temperature: 5.4774 | Peaceful queens: 0
# Step 290 | Temperature: 5.4226 | Peaceful queens: 0
# Step 291 | Temperature: 5.3684 | Peaceful queens: 0
# Step 292 | Temperature: 5.3147 | Peaceful queens: 0
# Step 293 | Temperature: 5.2615 | Peaceful queens: 0
# Step 294 | Temperature: 5.2089 | Peaceful queens: 0
# Step 295 | Temperature: 5.1568 | Peaceful queens: 0
# Step 296 | Temperature: 5.1053 | Peaceful queens: 0
# Step 297 | Temperature: 5.0542 | Peaceful queens: 1
# Step 298 | Temperature: 5.0037 | Peaceful queens: 0
# Step 299 | Temperature: 4.9536 | Peaceful queens: 1
# Step 300 | Temperature: 4.9041 | Peaceful queens: 1
# Step 301 | Temperature: 4.8550 | Peaceful queens: 1
# Step 302 | Temperature: 4.8065 | Peaceful queens: 1
# Step 303 | Temperature: 4.7584 | Peaceful queens: 1
# Step 304 | Temperature: 4.7108 | Peaceful queens: 0
# Step 305 | Temperature: 4.6637 | Peaceful queens: 0
# Step 306 | Temperature: 4.6171 | Peaceful queens: 1
# Step 307 | Temperature: 4.5709 | Peaceful queens: 2
# Step 308 | Temperature: 4.5252 | Peaceful queens: 3
# Step 309 | Temperature: 4.4800 | Peaceful queens: 3
# Step 310 | Temperature: 4.4352 | Peaceful queens: 1
# Step 311 | Temperature: 4.3908 | Peaceful queens: 1
# Step 312 | Temperature: 4.3469 | Peaceful queens: 0
# Step 313 | Temperature: 4.3034 | Peaceful queens: 0
# Step 314 | Temperature: 4.2604 | Peaceful queens: 0
# Step 315 | Temperature: 4.2178 | Peaceful queens: 0
# Step 316 | Temperature: 4.1756 | Peaceful queens: 1
# Step 317 | Temperature: 4.1339 | Peaceful queens: 1
# Step 318 | Temperature: 4.0925 | Peaceful queens: 2
# Step 319 | Temperature: 4.0516 | Peaceful queens: 1
# Step 320 | Temperature: 4.0111 | Peaceful queens: 1
# Step 321 | Temperature: 3.9710 | Peaceful queens: 0
# Step 322 | Temperature: 3.9313 | Peaceful queens: 0
# Step 323 | Temperature: 3.8920 | Peaceful queens: 0
# Step 324 | Temperature: 3.8530 | Peaceful queens: 1
# Step 325 | Temperature: 3.8145 | Peaceful queens: 2
# Step 326 | Temperature: 3.7764 | Peaceful queens: 1
# Step 327 | Temperature: 3.7386 | Peaceful queens: 1
# Step 328 | Temperature: 3.7012 | Peaceful queens: 1
# Step 329 | Temperature: 3.6642 | Peaceful queens: 0
# Step 330 | Temperature: 3.6276 | Peaceful queens: 1
# Step 331 | Temperature: 3.5913 | Peaceful queens: 1
# Step 332 | Temperature: 3.5554 | Peaceful queens: 1
# Step 333 | Temperature: 3.5198 | Peaceful queens: 2
# Step 334 | Temperature: 3.4846 | Peaceful queens: 2
# Step 335 | Temperature: 3.4498 | Peaceful queens: 1
# Step 336 | Temperature: 3.4153 | Peaceful queens: 2
# Step 337 | Temperature: 3.3811 | Peaceful queens: 0
# Step 338 | Temperature: 3.3473 | Peaceful queens: 0
# Step 339 | Temperature: 3.3138 | Peaceful queens: 0
# Step 340 | Temperature: 3.2807 | Peaceful queens: 0
# Step 341 | Temperature: 3.2479 | Peaceful queens: 0
# Step 342 | Temperature: 3.2154 | Peaceful queens: 0
# Step 343 | Temperature: 3.1833 | Peaceful queens: 0
# Step 344 | Temperature: 3.1514 | Peaceful queens: 1
# Step 345 | Temperature: 3.1199 | Peaceful queens: 2
# Step 346 | Temperature: 3.0887 | Peaceful queens: 2
# Step 347 | Temperature: 3.0578 | Peaceful queens: 2
# Step 348 | Temperature: 3.0272 | Peaceful queens: 2
# Step 349 | Temperature: 2.9970 | Peaceful queens: 2
# Step 350 | Temperature: 2.9670 | Peaceful queens: 1
# Step 351 | Temperature: 2.9373 | Peaceful queens: 2
# Step 352 | Temperature: 2.9080 | Peaceful queens: 2
# Step 353 | Temperature: 2.8789 | Peaceful queens: 2
# Step 354 | Temperature: 2.8501 | Peaceful queens: 2
# Step 355 | Temperature: 2.8216 | Peaceful queens: 1
# Step 356 | Temperature: 2.7934 | Peaceful queens: 1
# Step 357 | Temperature: 2.7654 | Peaceful queens: 1
# Step 358 | Temperature: 2.7378 | Peaceful queens: 1
# Step 359 | Temperature: 2.7104 | Peaceful queens: 1
# Step 360 | Temperature: 2.6833 | Peaceful queens: 0
# Step 361 | Temperature: 2.6565 | Peaceful queens: 0
# Step 362 | Temperature: 2.6299 | Peaceful queens: 0
# Step 363 | Temperature: 2.6036 | Peaceful queens: 0
# Step 364 | Temperature: 2.5776 | Peaceful queens: 2
# Step 365 | Temperature: 2.5518 | Peaceful queens: 1
# Step 366 | Temperature: 2.5263 | Peaceful queens: 1
# Step 367 | Temperature: 2.5010 | Peaceful queens: 0
# Step 368 | Temperature: 2.4760 | Peaceful queens: 0
# Step 369 | Temperature: 2.4512 | Peaceful queens: 0
# Step 370 | Temperature: 2.4267 | Peaceful queens: 0
# Step 371 | Temperature: 2.4025 | Peaceful queens: 2
# Step 372 | Temperature: 2.3784 | Peaceful queens: 2
# Step 373 | Temperature: 2.3547 | Peaceful queens: 2
# Step 374 | Temperature: 2.3311 | Peaceful queens: 1
# Step 375 | Temperature: 2.3078 | Peaceful queens: 1
# Step 376 | Temperature: 2.2847 | Peaceful queens: 0
# Step 377 | Temperature: 2.2619 | Peaceful queens: 0
# Step 378 | Temperature: 2.2393 | Peaceful queens: 0
# Step 379 | Temperature: 2.2169 | Peaceful queens: 0
# Step 380 | Temperature: 2.1947 | Peaceful queens: 0
# Step 381 | Temperature: 2.1727 | Peaceful queens: 1
# Step 382 | Temperature: 2.1510 | Peaceful queens: 0
# Step 383 | Temperature: 2.1295 | Peaceful queens: 0
# Step 384 | Temperature: 2.1082 | Peaceful queens: 0
# Step 385 | Temperature: 2.0871 | Peaceful queens: 0
# Step 386 | Temperature: 2.0663 | Peaceful queens: 0
# Step 387 | Temperature: 2.0456 | Peaceful queens: 0
# Step 388 | Temperature: 2.0251 | Peaceful queens: 1
# Step 389 | Temperature: 2.0049 | Peaceful queens: 1
# Step 390 | Temperature: 1.9848 | Peaceful queens: 0
# Step 391 | Temperature: 1.9650 | Peaceful queens: 0
# Step 392 | Temperature: 1.9453 | Peaceful queens: 0
# Step 393 | Temperature: 1.9259 | Peaceful queens: 1
# Step 394 | Temperature: 1.9066 | Peaceful queens: 2
# Step 395 | Temperature: 1.8876 | Peaceful queens: 2
# Step 396 | Temperature: 1.8687 | Peaceful queens: 4
# Step 397 | Temperature: 1.8500 | Peaceful queens: 4
# Step 398 | Temperature: 1.8315 | Peaceful queens: 4
# Step 399 | Temperature: 1.8132 | Peaceful queens: 5
# Step 400 | Temperature: 1.7951 | Peaceful queens: 3
# Step 401 | Temperature: 1.7771 | Peaceful queens: 4
# Step 402 | Temperature: 1.7593 | Peaceful queens: 4
# Step 403 | Temperature: 1.7417 | Peaceful queens: 4
# Step 404 | Temperature: 1.7243 | Peaceful queens: 4
# Step 405 | Temperature: 1.7071 | Peaceful queens: 4
# Step 406 | Temperature: 1.6900 | Peaceful queens: 4
# Step 407 | Temperature: 1.6731 | Peaceful queens: 3
# Step 408 | Temperature: 1.6564 | Peaceful queens: 4
# Step 409 | Temperature: 1.6398 | Peaceful queens: 5
# Step 410 | Temperature: 1.6234 | Peaceful queens: 4
# Step 411 | Temperature: 1.6072 | Peaceful queens: 5
# Step 412 | Temperature: 1.5911 | Peaceful queens: 5
# Step 413 | Temperature: 1.5752 | Peaceful queens: 5
# Step 414 | Temperature: 1.5594 | Peaceful queens: 5
# Step 415 | Temperature: 1.5439 | Peaceful queens: 5
# Step 416 | Temperature: 1.5284 | Peaceful queens: 5
# Step 417 | Temperature: 1.5131 | Peaceful queens: 4
# Step 418 | Temperature: 1.4980 | Peaceful queens: 4
# Step 419 | Temperature: 1.4830 | Peaceful queens: 4
# Step 420 | Temperature: 1.4682 | Peaceful queens: 4
# Step 421 | Temperature: 1.4535 | Peaceful queens: 4
# Step 422 | Temperature: 1.4390 | Peaceful queens: 4
# Step 423 | Temperature: 1.4246 | Peaceful queens: 4
# Step 424 | Temperature: 1.4103 | Peaceful queens: 4
# Step 425 | Temperature: 1.3962 | Peaceful queens: 2
# Step 426 | Temperature: 1.3823 | Peaceful queens: 1
# Step 427 | Temperature: 1.3684 | Peaceful queens: 1
# Step 428 | Temperature: 1.3548 | Peaceful queens: 2
# Step 429 | Temperature: 1.3412 | Peaceful queens: 2
# Step 430 | Temperature: 1.3278 | Peaceful queens: 2
# Step 431 | Temperature: 1.3145 | Peaceful queens: 2
# Step 432 | Temperature: 1.3014 | Peaceful queens: 2
# Step 433 | Temperature: 1.2884 | Peaceful queens: 1
# Step 434 | Temperature: 1.2755 | Peaceful queens: 2
# Step 435 | Temperature: 1.2627 | Peaceful queens: 2
# Step 436 | Temperature: 1.2501 | Peaceful queens: 2
# Step 437 | Temperature: 1.2376 | Peaceful queens: 1
# Step 438 | Temperature: 1.2252 | Peaceful queens: 1
# Step 439 | Temperature: 1.2130 | Peaceful queens: 0
# Step 440 | Temperature: 1.2008 | Peaceful queens: 0
# Step 441 | Temperature: 1.1888 | Peaceful queens: 0
# Step 442 | Temperature: 1.1769 | Peaceful queens: 0
# Step 443 | Temperature: 1.1652 | Peaceful queens: 0
# Step 444 | Temperature: 1.1535 | Peaceful queens: 0
# Step 445 | Temperature: 1.1420 | Peaceful queens: 1
# Step 446 | Temperature: 1.1306 | Peaceful queens: 1
# Step 447 | Temperature: 1.1193 | Peaceful queens: 1
# Step 448 | Temperature: 1.1081 | Peaceful queens: 1
# Step 449 | Temperature: 1.0970 | Peaceful queens: 1
# Step 450 | Temperature: 1.0860 | Peaceful queens: 1
# Step 451 | Temperature: 1.0752 | Peaceful queens: 1
# Step 452 | Temperature: 1.0644 | Peaceful queens: 2
# Step 453 | Temperature: 1.0538 | Peaceful queens: 1
# Step 454 | Temperature: 1.0432 | Peaceful queens: 1
# Step 455 | Temperature: 1.0328 | Peaceful queens: 1
# Step 456 | Temperature: 1.0225 | Peaceful queens: 0
# Step 457 | Temperature: 1.0122 | Peaceful queens: 0
# Step 458 | Temperature: 1.0021 | Peaceful queens: 0
# Step 459 | Temperature: 0.9921 | Peaceful queens: 1
# Step 460 | Temperature: 0.9822 | Peaceful queens: 0
# Step 461 | Temperature: 0.9724 | Peaceful queens: 0
# Step 462 | Temperature: 0.9626 | Peaceful queens: 2
# Step 463 | Temperature: 0.9530 | Peaceful queens: 2
# Step 464 | Temperature: 0.9435 | Peaceful queens: 2
# Step 465 | Temperature: 0.9340 | Peaceful queens: 2
# Step 466 | Temperature: 0.9247 | Peaceful queens: 2
# Step 467 | Temperature: 0.9155 | Peaceful queens: 1
# Step 468 | Temperature: 0.9063 | Peaceful queens: 1
# Step 469 | Temperature: 0.8972 | Peaceful queens: 1
# Step 470 | Temperature: 0.8883 | Peaceful queens: 1
# Step 471 | Temperature: 0.8794 | Peaceful queens: 2
# Step 472 | Temperature: 0.8706 | Peaceful queens: 2
# Step 473 | Temperature: 0.8619 | Peaceful queens: 2
# Step 474 | Temperature: 0.8533 | Peaceful queens: 2
# Step 475 | Temperature: 0.8447 | Peaceful queens: 2
# Step 476 | Temperature: 0.8363 | Peaceful queens: 4
# Step 477 | Temperature: 0.8279 | Peaceful queens: 4
# Step 478 | Temperature: 0.8196 | Peaceful queens: 4
# Step 479 | Temperature: 0.8114 | Peaceful queens: 4
# Step 480 | Temperature: 0.8033 | Peaceful queens: 4
# Step 481 | Temperature: 0.7953 | Peaceful queens: 4
# Step 482 | Temperature: 0.7873 | Peaceful queens: 4
# Step 483 | Temperature: 0.7795 | Peaceful queens: 4
# Step 484 | Temperature: 0.7717 | Peaceful queens: 3
# Step 485 | Temperature: 0.7640 | Peaceful queens: 3
# Step 486 | Temperature: 0.7563 | Peaceful queens: 3
# Step 487 | Temperature: 0.7488 | Peaceful queens: 3
# Step 488 | Temperature: 0.7413 | Peaceful queens: 4
# Step 489 | Temperature: 0.7339 | Peaceful queens: 4
# Step 490 | Temperature: 0.7265 | Peaceful queens: 4
# Step 491 | Temperature: 0.7193 | Peaceful queens: 3
# Step 492 | Temperature: 0.7121 | Peaceful queens: 3
# Step 493 | Temperature: 0.7049 | Peaceful queens: 3
# Step 494 | Temperature: 0.6979 | Peaceful queens: 4
# Step 495 | Temperature: 0.6909 | Peaceful queens: 4
# Step 496 | Temperature: 0.6840 | Peaceful queens: 4
# Step 497 | Temperature: 0.6772 | Peaceful queens: 4
# Step 498 | Temperature: 0.6704 | Peaceful queens: 4
# Step 499 | Temperature: 0.6637 | Peaceful queens: 4
# Step 500 | Temperature: 0.6570 | Peaceful queens: 4
# Step 501 | Temperature: 0.6505 | Peaceful queens: 4
# Step 502 | Temperature: 0.6440 | Peaceful queens: 4
# Step 503 | Temperature: 0.6375 | Peaceful queens: 4
# Step 504 | Temperature: 0.6312 | Peaceful queens: 4
# Step 505 | Temperature: 0.6248 | Peaceful queens: 4
# Step 506 | Temperature: 0.6186 | Peaceful queens: 4
# Step 507 | Temperature: 0.6124 | Peaceful queens: 4
# Step 508 | Temperature: 0.6063 | Peaceful queens: 4
# Step 509 | Temperature: 0.6002 | Peaceful queens: 4
# Step 510 | Temperature: 0.5942 | Peaceful queens: 3
# Step 511 | Temperature: 0.5883 | Peaceful queens: 3
# Step 512 | Temperature: 0.5824 | Peaceful queens: 3
# Step 513 | Temperature: 0.5766 | Peaceful queens: 2
# Step 514 | Temperature: 0.5708 | Peaceful queens: 2
# Step 515 | Temperature: 0.5651 | Peaceful queens: 2
# Step 516 | Temperature: 0.5594 | Peaceful queens: 2
# Step 517 | Temperature: 0.5539 | Peaceful queens: 2
# Step 518 | Temperature: 0.5483 | Peaceful queens: 3
# Step 519 | Temperature: 0.5428 | Peaceful queens: 3
# Step 520 | Temperature: 0.5374 | Peaceful queens: 4
# Step 521 | Temperature: 0.5320 | Peaceful queens: 4
# Step 522 | Temperature: 0.5267 | Peaceful queens: 4
# Step 523 | Temperature: 0.5214 | Peaceful queens: 4
# Step 524 | Temperature: 0.5162 | Peaceful queens: 4
# Step 525 | Temperature: 0.5111 | Peaceful queens: 4
# Step 526 | Temperature: 0.5060 | Peaceful queens: 4
# Step 527 | Temperature: 0.5009 | Peaceful queens: 4
# Step 528 | Temperature: 0.4959 | Peaceful queens: 4
# Step 529 | Temperature: 0.4909 | Peaceful queens: 4
# Step 530 | Temperature: 0.4860 | Peaceful queens: 4
# Step 531 | Temperature: 0.4812 | Peaceful queens: 4
# Step 532 | Temperature: 0.4763 | Peaceful queens: 4
# Step 533 | Temperature: 0.4716 | Peaceful queens: 5
# Step 534 | Temperature: 0.4669 | Peaceful queens: 6
# Step 535 | Temperature: 0.4622 | Peaceful queens: 6
# Step 536 | Temperature: 0.4576 | Peaceful queens: 6
# Step 537 | Temperature: 0.4530 | Peaceful queens: 6
# Step 538 | Temperature: 0.4485 | Peaceful queens: 6
# Step 539 | Temperature: 0.4440 | Peaceful queens: 6
# Step 540 | Temperature: 0.4395 | Peaceful queens: 6
# Step 541 | Temperature: 0.4352 | Peaceful queens: 6
# Step 542 | Temperature: 0.4308 | Peaceful queens: 6
# Step 543 | Temperature: 0.4265 | Peaceful queens: 6
# Step 544 | Temperature: 0.4222 | Peaceful queens: 6
# Step 545 | Temperature: 0.4180 | Peaceful queens: 6
# Step 546 | Temperature: 0.4138 | Peaceful queens: 6
# Step 547 | Temperature: 0.4097 | Peaceful queens: 6
# Step 548 | Temperature: 0.4056 | Peaceful queens: 6
# Step 549 | Temperature: 0.4015 | Peaceful queens: 6
# Step 550 | Temperature: 0.3975 | Peaceful queens: 6
# Step 551 | Temperature: 0.3935 | Peaceful queens: 6
# Step 552 | Temperature: 0.3896 | Peaceful queens: 6
# Step 553 | Temperature: 0.3857 | Peaceful queens: 6
# Step 554 | Temperature: 0.3819 | Peaceful queens: 6
# Step 555 | Temperature: 0.3780 | Peaceful queens: 6
# Step 556 | Temperature: 0.3743 | Peaceful queens: 6
# Step 557 | Temperature: 0.3705 | Peaceful queens: 6
# Step 558 | Temperature: 0.3668 | Peaceful queens: 6
# Step 559 | Temperature: 0.3631 | Peaceful queens: 6
# Step 560 | Temperature: 0.3595 | Peaceful queens: 6
# Step 561 | Temperature: 0.3559 | Peaceful queens: 6
# Step 562 | Temperature: 0.3524 | Peaceful queens: 5
# Step 563 | Temperature: 0.3488 | Peaceful queens: 5
# Step 564 | Temperature: 0.3453 | Peaceful queens: 5
# Step 565 | Temperature: 0.3419 | Peaceful queens: 5
# Step 566 | Temperature: 0.3385 | Peaceful queens: 5
# Step 567 | Temperature: 0.3351 | Peaceful queens: 5
# Step 568 | Temperature: 0.3317 | Peaceful queens: 5
# Step 569 | Temperature: 0.3284 | Peaceful queens: 4
# Step 570 | Temperature: 0.3251 | Peaceful queens: 4
# Step 571 | Temperature: 0.3219 | Peaceful queens: 4
# Step 572 | Temperature: 0.3187 | Peaceful queens: 4
# Step 573 | Temperature: 0.3155 | Peaceful queens: 4
# Step 574 | Temperature: 0.3123 | Peaceful queens: 4
# Step 575 | Temperature: 0.3092 | Peaceful queens: 4
# Step 576 | Temperature: 0.3061 | Peaceful queens: 4
# Step 577 | Temperature: 0.3030 | Peaceful queens: 4
# Step 578 | Temperature: 0.3000 | Peaceful queens: 4
# Step 579 | Temperature: 0.2970 | Peaceful queens: 4
# Step 580 | Temperature: 0.2940 | Peaceful queens: 4
# Step 581 | Temperature: 0.2911 | Peaceful queens: 4
# Step 582 | Temperature: 0.2882 | Peaceful queens: 4
# Step 583 | Temperature: 0.2853 | Peaceful queens: 4
# Step 584 | Temperature: 0.2825 | Peaceful queens: 4
# Step 585 | Temperature: 0.2796 | Peaceful queens: 4
# Step 586 | Temperature: 0.2768 | Peaceful queens: 4
# Step 587 | Temperature: 0.2741 | Peaceful queens: 4
# Step 588 | Temperature: 0.2713 | Peaceful queens: 5
# Step 589 | Temperature: 0.2686 | Peaceful queens: 5
# Step 590 | Temperature: 0.2659 | Peaceful queens: 5
# Step 591 | Temperature: 0.2633 | Peaceful queens: 6
# Step 592 | Temperature: 0.2606 | Peaceful queens: 6
# Step 593 | Temperature: 0.2580 | Peaceful queens: 6
# Step 594 | Temperature: 0.2554 | Peaceful queens: 6
# Step 595 | Temperature: 0.2529 | Peaceful queens: 6
# Step 596 | Temperature: 0.2504 | Peaceful queens: 6
# Step 597 | Temperature: 0.2479 | Peaceful queens: 6
# Step 598 | Temperature: 0.2454 | Peaceful queens: 6
# Step 599 | Temperature: 0.2429 | Peaceful queens: 6
# Step 600 | Temperature: 0.2405 | Peaceful queens: 6
# Step 601 | Temperature: 0.2381 | Peaceful queens: 6
# Step 602 | Temperature: 0.2357 | Peaceful queens: 6
# Step 603 | Temperature: 0.2334 | Peaceful queens: 6
# Step 604 | Temperature: 0.2310 | Peaceful queens: 6
# Step 605 | Temperature: 0.2287 | Peaceful queens: 6
# Step 606 | Temperature: 0.2264 | Peaceful queens: 6
# Step 607 | Temperature: 0.2242 | Peaceful queens: 6
# Step 608 | Temperature: 0.2219 | Peaceful queens: 6
# Step 609 | Temperature: 0.2197 | Peaceful queens: 6
# Step 610 | Temperature: 0.2175 | Peaceful queens: 6
# Step 611 | Temperature: 0.2153 | Peaceful queens: 6
# Step 612 | Temperature: 0.2132 | Peaceful queens: 6
# Step 613 | Temperature: 0.2110 | Peaceful queens: 6
# Step 614 | Temperature: 0.2089 | Peaceful queens: 6
# Step 615 | Temperature: 0.2068 | Peaceful queens: 6
# Step 616 | Temperature: 0.2048 | Peaceful queens: 6
# Step 617 | Temperature: 0.2027 | Peaceful queens: 6
# Step 618 | Temperature: 0.2007 | Peaceful queens: 6
# Step 619 | Temperature: 0.1987 | Peaceful queens: 6
# Step 620 | Temperature: 0.1967 | Peaceful queens: 6
# Step 621 | Temperature: 0.1947 | Peaceful queens: 6
# Step 622 | Temperature: 0.1928 | Peaceful queens: 6
# Step 623 | Temperature: 0.1909 | Peaceful queens: 6
# Step 624 | Temperature: 0.1890 | Peaceful queens: 6
# Step 625 | Temperature: 0.1871 | Peaceful queens: 6
# Step 626 | Temperature: 0.1852 | Peaceful queens: 6
# Step 627 | Temperature: 0.1833 | Peaceful queens: 6
# Step 628 | Temperature: 0.1815 | Peaceful queens: 6
# Step 629 | Temperature: 0.1797 | Peaceful queens: 6
# Step 630 | Temperature: 0.1779 | Peaceful queens: 6
# Step 631 | Temperature: 0.1761 | Peaceful queens: 6
# Step 632 | Temperature: 0.1744 | Peaceful queens: 6
# Step 633 | Temperature: 0.1726 | Peaceful queens: 6
# Step 634 | Temperature: 0.1709 | Peaceful queens: 6
# Step 635 | Temperature: 0.1692 | Peaceful queens: 6
# Step 636 | Temperature: 0.1675 | Peaceful queens: 6
# Step 637 | Temperature: 0.1658 | Peaceful queens: 6
# Step 638 | Temperature: 0.1642 | Peaceful queens: 6
# Step 639 | Temperature: 0.1625 | Peaceful queens: 6
# Step 640 | Temperature: 0.1609 | Peaceful queens: 6
# Step 641 | Temperature: 0.1593 | Peaceful queens: 6
# Step 642 | Temperature: 0.1577 | Peaceful queens: 6
# Step 643 | Temperature: 0.1561 | Peaceful queens: 6
# Step 644 | Temperature: 0.1545 | Peaceful queens: 6
# Step 645 | Temperature: 0.1530 | Peaceful queens: 6
# Step 646 | Temperature: 0.1515 | Peaceful queens: 6
# Step 647 | Temperature: 0.1500 | Peaceful queens: 6
# Step 648 | Temperature: 0.1485 | Peaceful queens: 6
# Step 649 | Temperature: 0.1470 | Peaceful queens: 6
# Step 650 | Temperature: 0.1455 | Peaceful queens: 6
# Step 651 | Temperature: 0.1440 | Peaceful queens: 6
# Step 652 | Temperature: 0.1426 | Peaceful queens: 6
# Step 653 | Temperature: 0.1412 | Peaceful queens: 6
# Step 654 | Temperature: 0.1398 | Peaceful queens: 6
# Step 655 | Temperature: 0.1384 | Peaceful queens: 6
# Step 656 | Temperature: 0.1370 | Peaceful queens: 6
# Step 657 | Temperature: 0.1356 | Peaceful queens: 6
# Step 658 | Temperature: 0.1343 | Peaceful queens: 6
# Step 659 | Temperature: 0.1329 | Peaceful queens: 6
# Step 660 | Temperature: 0.1316 | Peaceful queens: 6
# Step 661 | Temperature: 0.1303 | Peaceful queens: 6
# Step 662 | Temperature: 0.1290 | Peaceful queens: 6
# Step 663 | Temperature: 0.1277 | Peaceful queens: 6
# Step 664 | Temperature: 0.1264 | Peaceful queens: 6
# Step 665 | Temperature: 0.1251 | Peaceful queens: 6
# Step 666 | Temperature: 0.1239 | Peaceful queens: 6
# Step 667 | Temperature: 0.1227 | Peaceful queens: 6
# Step 668 | Temperature: 0.1214 | Peaceful queens: 6
# Step 669 | Temperature: 0.1202 | Peaceful queens: 6
# Step 670 | Temperature: 0.1190 | Peaceful queens: 6
# Step 671 | Temperature: 0.1178 | Peaceful queens: 6
# Step 672 | Temperature: 0.1166 | Peaceful queens: 6
# Step 673 | Temperature: 0.1155 | Peaceful queens: 6
# Step 674 | Temperature: 0.1143 | Peaceful queens: 6
# Step 675 | Temperature: 0.1132 | Peaceful queens: 6
# Step 676 | Temperature: 0.1120 | Peaceful queens: 6
# Step 677 | Temperature: 0.1109 | Peaceful queens: 6
# Step 678 | Temperature: 0.1098 | Peaceful queens: 6
# Step 679 | Temperature: 0.1087 | Peaceful queens: 6
# Step 680 | Temperature: 0.1076 | Peaceful queens: 6
# Step 681 | Temperature: 0.1066 | Peaceful queens: 6
# Step 682 | Temperature: 0.1055 | Peaceful queens: 6
# Step 683 | Temperature: 0.1044 | Peaceful queens: 6
# Step 684 | Temperature: 0.1034 | Peaceful queens: 6
# Step 685 | Temperature: 0.1024 | Peaceful queens: 6
# Step 686 | Temperature: 0.1013 | Peaceful queens: 6
# Step 687 | Temperature: 0.1003 | Peaceful queens: 6
# Step 688 | Temperature: 0.0993 | Peaceful queens: 6
# Step 689 | Temperature: 0.0983 | Peaceful queens: 6
# Step 690 | Temperature: 0.0973 | Peaceful queens: 6
# Step 691 | Temperature: 0.0964 | Peaceful queens: 6
# Step 692 | Temperature: 0.0954 | Peaceful queens: 6
# Step 693 | Temperature: 0.0944 | Peaceful queens: 6
# Step 694 | Temperature: 0.0935 | Peaceful queens: 6
# Step 695 | Temperature: 0.0926 | Peaceful queens: 6
# Step 696 | Temperature: 0.0916 | Peaceful queens: 6
# Step 697 | Temperature: 0.0907 | Peaceful queens: 6
# Step 698 | Temperature: 0.0898 | Peaceful queens: 6
# Step 699 | Temperature: 0.0889 | Peaceful queens: 6
# Step 700 | Temperature: 0.0880 | Peaceful queens: 6
# Step 701 | Temperature: 0.0872 | Peaceful queens: 6
# Step 702 | Temperature: 0.0863 | Peaceful queens: 6
# Step 703 | Temperature: 0.0854 | Peaceful queens: 6
# Step 704 | Temperature: 0.0846 | Peaceful queens: 6
# Step 705 | Temperature: 0.0837 | Peaceful queens: 6
# Step 706 | Temperature: 0.0829 | Peaceful queens: 6
# Step 707 | Temperature: 0.0821 | Peaceful queens: 6
# Step 708 | Temperature: 0.0812 | Peaceful queens: 6
# Step 709 | Temperature: 0.0804 | Peaceful queens: 6
# Step 710 | Temperature: 0.0796 | Peaceful queens: 6
# Step 711 | Temperature: 0.0788 | Peaceful queens: 6
# Step 712 | Temperature: 0.0780 | Peaceful queens: 6
# Step 713 | Temperature: 0.0772 | Peaceful queens: 6
# Step 714 | Temperature: 0.0765 | Peaceful queens: 6
# Step 715 | Temperature: 0.0757 | Peaceful queens: 6
# Step 716 | Temperature: 0.0750 | Peaceful queens: 6
# Step 717 | Temperature: 0.0742 | Peaceful queens: 6
# Step 718 | Temperature: 0.0735 | Peaceful queens: 6
# Step 719 | Temperature: 0.0727 | Peaceful queens: 6
# Step 720 | Temperature: 0.0720 | Peaceful queens: 6
# Step 721 | Temperature: 0.0713 | Peaceful queens: 6
# Step 722 | Temperature: 0.0706 | Peaceful queens: 6
# Step 723 | Temperature: 0.0699 | Peaceful queens: 6
# Step 724 | Temperature: 0.0692 | Peaceful queens: 6
# Step 725 | Temperature: 0.0685 | Peaceful queens: 6
# Step 726 | Temperature: 0.0678 | Peaceful queens: 6
# Step 727 | Temperature: 0.0671 | Peaceful queens: 6
# Step 728 | Temperature: 0.0664 | Peaceful queens: 6
# Step 729 | Temperature: 0.0658 | Peaceful queens: 6
# Step 730 | Temperature: 0.0651 | Peaceful queens: 6
# Step 731 | Temperature: 0.0645 | Peaceful queens: 6
# Step 732 | Temperature: 0.0638 | Peaceful queens: 6
# Step 733 | Temperature: 0.0632 | Peaceful queens: 6
# Step 734 | Temperature: 0.0626 | Peaceful queens: 6
# Step 735 | Temperature: 0.0619 | Peaceful queens: 6
# Step 736 | Temperature: 0.0613 | Peaceful queens: 6
# Step 737 | Temperature: 0.0607 | Peaceful queens: 6
# Step 738 | Temperature: 0.0601 | Peaceful queens: 6
# Step 739 | Temperature: 0.0595 | Peaceful queens: 6
# Step 740 | Temperature: 0.0589 | Peaceful queens: 6
# Step 741 | Temperature: 0.0583 | Peaceful queens: 6
# Step 742 | Temperature: 0.0577 | Peaceful queens: 6
# Step 743 | Temperature: 0.0571 | Peaceful queens: 6
# Step 744 | Temperature: 0.0566 | Peaceful queens: 6
# Step 745 | Temperature: 0.0560 | Peaceful queens: 6
# Step 746 | Temperature: 0.0554 | Peaceful queens: 6
# Step 747 | Temperature: 0.0549 | Peaceful queens: 6
# Step 748 | Temperature: 0.0543 | Peaceful queens: 6
# Step 749 | Temperature: 0.0538 | Peaceful queens: 6
# Step 750 | Temperature: 0.0533 | Peaceful queens: 6
# Step 751 | Temperature: 0.0527 | Peaceful queens: 6
# Step 752 | Temperature: 0.0522 | Peaceful queens: 6
# Step 753 | Temperature: 0.0517 | Peaceful queens: 6
# Step 754 | Temperature: 0.0512 | Peaceful queens: 6
# Step 755 | Temperature: 0.0506 | Peaceful queens: 6
# Step 756 | Temperature: 0.0501 | Peaceful queens: 6
# Step 757 | Temperature: 0.0496 | Peaceful queens: 6
# Step 758 | Temperature: 0.0491 | Peaceful queens: 6
# Step 759 | Temperature: 0.0487 | Peaceful queens: 6
# Step 760 | Temperature: 0.0482 | Peaceful queens: 6
# Step 761 | Temperature: 0.0477 | Peaceful queens: 6
# Step 762 | Temperature: 0.0472 | Peaceful queens: 6
# Step 763 | Temperature: 0.0467 | Peaceful queens: 6
# Step 764 | Temperature: 0.0463 | Peaceful queens: 6
# Step 765 | Temperature: 0.0458 | Peaceful queens: 6
# Step 766 | Temperature: 0.0453 | Peaceful queens: 6
# Step 767 | Temperature: 0.0449 | Peaceful queens: 6
# Step 768 | Temperature: 0.0444 | Peaceful queens: 6
# Step 769 | Temperature: 0.0440 | Peaceful queens: 6
# Step 770 | Temperature: 0.0436 | Peaceful queens: 6
# Step 771 | Temperature: 0.0431 | Peaceful queens: 6
# Step 772 | Temperature: 0.0427 | Peaceful queens: 6
# Step 773 | Temperature: 0.0423 | Peaceful queens: 6
# Step 774 | Temperature: 0.0418 | Peaceful queens: 6
# Step 775 | Temperature: 0.0414 | Peaceful queens: 6
# Step 776 | Temperature: 0.0410 | Peaceful queens: 6
# Step 777 | Temperature: 0.0406 | Peaceful queens: 6
# Step 778 | Temperature: 0.0402 | Peaceful queens: 6
# Step 779 | Temperature: 0.0398 | Peaceful queens: 6
# Step 780 | Temperature: 0.0394 | Peaceful queens: 6
# Step 781 | Temperature: 0.0390 | Peaceful queens: 6
# Step 782 | Temperature: 0.0386 | Peaceful queens: 6
# Step 783 | Temperature: 0.0382 | Peaceful queens: 6
# Step 784 | Temperature: 0.0378 | Peaceful queens: 6
# Step 785 | Temperature: 0.0375 | Peaceful queens: 6
# Step 786 | Temperature: 0.0371 | Peaceful queens: 6
# Step 787 | Temperature: 0.0367 | Peaceful queens: 6
# Step 788 | Temperature: 0.0364 | Peaceful queens: 6
# Step 789 | Temperature: 0.0360 | Peaceful queens: 6
# Step 790 | Temperature: 0.0356 | Peaceful queens: 6
# Step 791 | Temperature: 0.0353 | Peaceful queens: 6
# Step 792 | Temperature: 0.0349 | Peaceful queens: 6
# Step 793 | Temperature: 0.0346 | Peaceful queens: 6
# Step 794 | Temperature: 0.0342 | Peaceful queens: 6
# Step 795 | Temperature: 0.0339 | Peaceful queens: 6
# Step 796 | Temperature: 0.0335 | Peaceful queens: 6
# Step 797 | Temperature: 0.0332 | Peaceful queens: 6
# Step 798 | Temperature: 0.0329 | Peaceful queens: 6
# Step 799 | Temperature: 0.0325 | Peaceful queens: 6
# Step 800 | Temperature: 0.0322 | Peaceful queens: 6
# Step 801 | Temperature: 0.0319 | Peaceful queens: 6
# Step 802 | Temperature: 0.0316 | Peaceful queens: 6
# Step 803 | Temperature: 0.0313 | Peaceful queens: 6
# Step 804 | Temperature: 0.0310 | Peaceful queens: 6
# Step 805 | Temperature: 0.0306 | Peaceful queens: 6
# Step 806 | Temperature: 0.0303 | Peaceful queens: 6
# Step 807 | Temperature: 0.0300 | Peaceful queens: 6
# Step 808 | Temperature: 0.0297 | Peaceful queens: 6
# Step 809 | Temperature: 0.0294 | Peaceful queens: 6
# Step 810 | Temperature: 0.0291 | Peaceful queens: 6
# Step 811 | Temperature: 0.0288 | Peaceful queens: 6
# Step 812 | Temperature: 0.0286 | Peaceful queens: 6
# Step 813 | Temperature: 0.0283 | Peaceful queens: 6
# Step 814 | Temperature: 0.0280 | Peaceful queens: 6
# Step 815 | Temperature: 0.0277 | Peaceful queens: 6
# Step 816 | Temperature: 0.0274 | Peaceful queens: 6
# Step 817 | Temperature: 0.0272 | Peaceful queens: 6
# Step 818 | Temperature: 0.0269 | Peaceful queens: 6
# Step 819 | Temperature: 0.0266 | Peaceful queens: 6
# Step 820 | Temperature: 0.0264 | Peaceful queens: 6
# Step 821 | Temperature: 0.0261 | Peaceful queens: 6
# Step 822 | Temperature: 0.0258 | Peaceful queens: 6
# Step 823 | Temperature: 0.0256 | Peaceful queens: 6
# Step 824 | Temperature: 0.0253 | Peaceful queens: 6
# Step 825 | Temperature: 0.0251 | Peaceful queens: 6
# Step 826 | Temperature: 0.0248 | Peaceful queens: 6
# Step 827 | Temperature: 0.0246 | Peaceful queens: 6
# Step 828 | Temperature: 0.0243 | Peaceful queens: 6
# Step 829 | Temperature: 0.0241 | Peaceful queens: 6
# Step 830 | Temperature: 0.0238 | Peaceful queens: 6
# Step 831 | Temperature: 0.0236 | Peaceful queens: 6
# Step 832 | Temperature: 0.0234 | Peaceful queens: 6
# Step 833 | Temperature: 0.0231 | Peaceful queens: 6
# Step 834 | Temperature: 0.0229 | Peaceful queens: 6
# Step 835 | Temperature: 0.0227 | Peaceful queens: 6
# Step 836 | Temperature: 0.0224 | Peaceful queens: 6
# Step 837 | Temperature: 0.0222 | Peaceful queens: 6
# Step 838 | Temperature: 0.0220 | Peaceful queens: 6
# Step 839 | Temperature: 0.0218 | Peaceful queens: 6
# Step 840 | Temperature: 0.0216 | Peaceful queens: 6
# Step 841 | Temperature: 0.0213 | Peaceful queens: 6
# Step 842 | Temperature: 0.0211 | Peaceful queens: 6
# Step 843 | Temperature: 0.0209 | Peaceful queens: 6
# Step 844 | Temperature: 0.0207 | Peaceful queens: 6
# Step 845 | Temperature: 0.0205 | Peaceful queens: 6
# Step 846 | Temperature: 0.0203 | Peaceful queens: 6
# Step 847 | Temperature: 0.0201 | Peaceful queens: 6
# Step 848 | Temperature: 0.0199 | Peaceful queens: 6
# Step 849 | Temperature: 0.0197 | Peaceful queens: 6
# Step 850 | Temperature: 0.0195 | Peaceful queens: 6
# Step 851 | Temperature: 0.0193 | Peaceful queens: 6
# Step 852 | Temperature: 0.0191 | Peaceful queens: 6
# Step 853 | Temperature: 0.0189 | Peaceful queens: 6
# Step 854 | Temperature: 0.0187 | Peaceful queens: 6
# Step 855 | Temperature: 0.0185 | Peaceful queens: 6
# Step 856 | Temperature: 0.0184 | Peaceful queens: 6
# Step 857 | Temperature: 0.0182 | Peaceful queens: 6
# Step 858 | Temperature: 0.0180 | Peaceful queens: 6
# Step 859 | Temperature: 0.0178 | Peaceful queens: 6
# Step 860 | Temperature: 0.0176 | Peaceful queens: 6
# Step 861 | Temperature: 0.0175 | Peaceful queens: 6
# Step 862 | Temperature: 0.0173 | Peaceful queens: 6
# Step 863 | Temperature: 0.0171 | Peaceful queens: 6
# Step 864 | Temperature: 0.0169 | Peaceful queens: 6
# Step 865 | Temperature: 0.0168 | Peaceful queens: 6
# Step 866 | Temperature: 0.0166 | Peaceful queens: 6
# Step 867 | Temperature: 0.0164 | Peaceful queens: 6
# Step 868 | Temperature: 0.0163 | Peaceful queens: 6
# Step 869 | Temperature: 0.0161 | Peaceful queens: 6
# Step 870 | Temperature: 0.0159 | Peaceful queens: 6
# Step 871 | Temperature: 0.0158 | Peaceful queens: 6
# Step 872 | Temperature: 0.0156 | Peaceful queens: 6
# Step 873 | Temperature: 0.0155 | Peaceful queens: 6
# Step 874 | Temperature: 0.0153 | Peaceful queens: 6
# Step 875 | Temperature: 0.0152 | Peaceful queens: 6
# Step 876 | Temperature: 0.0150 | Peaceful queens: 6
# Step 877 | Temperature: 0.0149 | Peaceful queens: 6
# Step 878 | Temperature: 0.0147 | Peaceful queens: 6
# Step 879 | Temperature: 0.0146 | Peaceful queens: 6
# Step 880 | Temperature: 0.0144 | Peaceful queens: 6
# Step 881 | Temperature: 0.0143 | Peaceful queens: 6
# Step 882 | Temperature: 0.0141 | Peaceful queens: 6
# Step 883 | Temperature: 0.0140 | Peaceful queens: 6
# Step 884 | Temperature: 0.0139 | Peaceful queens: 6
# Step 885 | Temperature: 0.0137 | Peaceful queens: 6
# Step 886 | Temperature: 0.0136 | Peaceful queens: 6
# Step 887 | Temperature: 0.0134 | Peaceful queens: 6
# Step 888 | Temperature: 0.0133 | Peaceful queens: 6
# Step 889 | Temperature: 0.0132 | Peaceful queens: 6
# Step 890 | Temperature: 0.0130 | Peaceful queens: 6
# Step 891 | Temperature: 0.0129 | Peaceful queens: 6
# Step 892 | Temperature: 0.0128 | Peaceful queens: 6
# Step 893 | Temperature: 0.0127 | Peaceful queens: 6
# Step 894 | Temperature: 0.0125 | Peaceful queens: 6
# Step 895 | Temperature: 0.0124 | Peaceful queens: 6
# Step 896 | Temperature: 0.0123 | Peaceful queens: 6
# Step 897 | Temperature: 0.0122 | Peaceful queens: 6
# Step 898 | Temperature: 0.0120 | Peaceful queens: 6
# Step 899 | Temperature: 0.0119 | Peaceful queens: 6
# Step 900 | Temperature: 0.0118 | Peaceful queens: 6
# Step 901 | Temperature: 0.0117 | Peaceful queens: 6
# Step 902 | Temperature: 0.0116 | Peaceful queens: 6
# Step 903 | Temperature: 0.0114 | Peaceful queens: 6
# Step 904 | Temperature: 0.0113 | Peaceful queens: 6
# Step 905 | Temperature: 0.0112 | Peaceful queens: 6
# Step 906 | Temperature: 0.0111 | Peaceful queens: 6
# Step 907 | Temperature: 0.0110 | Peaceful queens: 6
# Step 908 | Temperature: 0.0109 | Peaceful queens: 6
# Step 909 | Temperature: 0.0108 | Peaceful queens: 6
# Step 910 | Temperature: 0.0107 | Peaceful queens: 6
# Step 911 | Temperature: 0.0106 | Peaceful queens: 6
# Step 912 | Temperature: 0.0105 | Peaceful queens: 6
# Step 913 | Temperature: 0.0103 | Peaceful queens: 6
# Step 914 | Temperature: 0.0102 | Peaceful queens: 6
# Step 915 | Temperature: 0.0101 | Peaceful queens: 6
# Step 916 | Temperature: 0.0100 | Peaceful queens: 6
# Step 917 | Temperature: 0.0099 | Peaceful queens: 6
# Step 918 | Temperature: 0.0098 | Peaceful queens: 6
# Step 919 | Temperature: 0.0097 | Peaceful queens: 6
# Step 920 | Temperature: 0.0096 | Peaceful queens: 6
# Step 921 | Temperature: 0.0096 | Peaceful queens: 6
# Step 922 | Temperature: 0.0095 | Peaceful queens: 6
# Step 923 | Temperature: 0.0094 | Peaceful queens: 6
# Step 924 | Temperature: 0.0093 | Peaceful queens: 6
# Step 925 | Temperature: 0.0092 | Peaceful queens: 6
# Step 926 | Temperature: 0.0091 | Peaceful queens: 6
# Step 927 | Temperature: 0.0090 | Peaceful queens: 6
# Step 928 | Temperature: 0.0089 | Peaceful queens: 6
# Step 929 | Temperature: 0.0088 | Peaceful queens: 6
# Step 930 | Temperature: 0.0087 | Peaceful queens: 6
# Step 931 | Temperature: 0.0086 | Peaceful queens: 6
# Step 932 | Temperature: 0.0086 | Peaceful queens: 6
# Step 933 | Temperature: 0.0085 | Peaceful queens: 6
# Step 934 | Temperature: 0.0084 | Peaceful queens: 6
# Step 935 | Temperature: 0.0083 | Peaceful queens: 6
# Step 936 | Temperature: 0.0082 | Peaceful queens: 6
# Step 937 | Temperature: 0.0081 | Peaceful queens: 6
# Step 938 | Temperature: 0.0081 | Peaceful queens: 6
# Step 939 | Temperature: 0.0080 | Peaceful queens: 6
# Step 940 | Temperature: 0.0079 | Peaceful queens: 6
# Step 941 | Temperature: 0.0078 | Peaceful queens: 6
# Step 942 | Temperature: 0.0077 | Peaceful queens: 6
# Step 943 | Temperature: 0.0077 | Peaceful queens: 6
# Step 944 | Temperature: 0.0076 | Peaceful queens: 6
# Step 945 | Temperature: 0.0075 | Peaceful queens: 6
# Step 946 | Temperature: 0.0074 | Peaceful queens: 6
# Step 947 | Temperature: 0.0074 | Peaceful queens: 6
# Step 948 | Temperature: 0.0073 | Peaceful queens: 6
# Step 949 | Temperature: 0.0072 | Peaceful queens: 6
# Step 950 | Temperature: 0.0071 | Peaceful queens: 6
# Step 951 | Temperature: 0.0071 | Peaceful queens: 6
# Step 952 | Temperature: 0.0070 | Peaceful queens: 6
# Step 953 | Temperature: 0.0069 | Peaceful queens: 6
# Step 954 | Temperature: 0.0069 | Peaceful queens: 6
# Step 955 | Temperature: 0.0068 | Peaceful queens: 6
# Step 956 | Temperature: 0.0067 | Peaceful queens: 6
# Step 957 | Temperature: 0.0067 | Peaceful queens: 6
# Step 958 | Temperature: 0.0066 | Peaceful queens: 6
# Step 959 | Temperature: 0.0065 | Peaceful queens: 6
# Step 960 | Temperature: 0.0065 | Peaceful queens: 6
# Step 961 | Temperature: 0.0064 | Peaceful queens: 6
# Step 962 | Temperature: 0.0063 | Peaceful queens: 6
# Step 963 | Temperature: 0.0063 | Peaceful queens: 6
# Step 964 | Temperature: 0.0062 | Peaceful queens: 6
# Step 965 | Temperature: 0.0061 | Peaceful queens: 6
# Step 966 | Temperature: 0.0061 | Peaceful queens: 6
# Step 967 | Temperature: 0.0060 | Peaceful queens: 6
# Step 968 | Temperature: 0.0060 | Peaceful queens: 6
# Step 969 | Temperature: 0.0059 | Peaceful queens: 6
# Step 970 | Temperature: 0.0058 | Peaceful queens: 6
# Step 971 | Temperature: 0.0058 | Peaceful queens: 6
# Step 972 | Temperature: 0.0057 | Peaceful queens: 6
# Step 973 | Temperature: 0.0057 | Peaceful queens: 6
# Step 974 | Temperature: 0.0056 | Peaceful queens: 6
# Step 975 | Temperature: 0.0056 | Peaceful queens: 6
# Step 976 | Temperature: 0.0055 | Peaceful queens: 6
# Step 977 | Temperature: 0.0054 | Peaceful queens: 6
# Step 978 | Temperature: 0.0054 | Peaceful queens: 6
# Step 979 | Temperature: 0.0053 | Peaceful queens: 6
# Step 980 | Temperature: 0.0053 | Peaceful queens: 6
# Step 981 | Temperature: 0.0052 | Peaceful queens: 6
# Step 982 | Temperature: 0.0052 | Peaceful queens: 6
# Step 983 | Temperature: 0.0051 | Peaceful queens: 6
# Step 984 | Temperature: 0.0051 | Peaceful queens: 6
# Step 985 | Temperature: 0.0050 | Peaceful queens: 6
# Step 986 | Temperature: 0.0050 | Peaceful queens: 6
# Step 987 | Temperature: 0.0049 | Peaceful queens: 6
# Step 988 | Temperature: 0.0049 | Peaceful queens: 6
# Step 989 | Temperature: 0.0048 | Peaceful queens: 6
# Step 990 | Temperature: 0.0048 | Peaceful queens: 6
# Step 991 | Temperature: 0.0047 | Peaceful queens: 6
# Step 992 | Temperature: 0.0047 | Peaceful queens: 6
# Step 993 | Temperature: 0.0046 | Peaceful queens: 6
# Step 994 | Temperature: 0.0046 | Peaceful queens: 6
# Step 995 | Temperature: 0.0045 | Peaceful queens: 6
# Step 996 | Temperature: 0.0045 | Peaceful queens: 6
# Step 997 | Temperature: 0.0044 | Peaceful queens: 6
# Step 998 | Temperature: 0.0044 | Peaceful queens: 6
# Step 999 | Temperature: 0.0044 | Peaceful queens: 6
# Step 1000 | Temperature: 0.0043 | Peaceful queens: 6
# Step 1001 | Temperature: 0.0043 | Peaceful queens: 6
# Step 1002 | Temperature: 0.0042 | Peaceful queens: 6
# Step 1003 | Temperature: 0.0042 | Peaceful queens: 6
# Step 1004 | Temperature: 0.0041 | Peaceful queens: 6
# Step 1005 | Temperature: 0.0041 | Peaceful queens: 6
# Step 1006 | Temperature: 0.0041 | Peaceful queens: 6
# Step 1007 | Temperature: 0.0040 | Peaceful queens: 6
# Step 1008 | Temperature: 0.0040 | Peaceful queens: 6
# Step 1009 | Temperature: 0.0039 | Peaceful queens: 6
# Step 1010 | Temperature: 0.0039 | Peaceful queens: 6
# Step 1011 | Temperature: 0.0039 | Peaceful queens: 6
# Step 1012 | Temperature: 0.0038 | Peaceful queens: 6
# Step 1013 | Temperature: 0.0038 | Peaceful queens: 6
# Step 1014 | Temperature: 0.0038 | Peaceful queens: 6
# Step 1015 | Temperature: 0.0037 | Peaceful queens: 6
# Step 1016 | Temperature: 0.0037 | Peaceful queens: 6
# Step 1017 | Temperature: 0.0036 | Peaceful queens: 6
# Step 1018 | Temperature: 0.0036 | Peaceful queens: 6
# Step 1019 | Temperature: 0.0036 | Peaceful queens: 6
# Step 1020 | Temperature: 0.0035 | Peaceful queens: 6
# Step 1021 | Temperature: 0.0035 | Peaceful queens: 6
# Step 1022 | Temperature: 0.0035 | Peaceful queens: 6
# Step 1023 | Temperature: 0.0034 | Peaceful queens: 6
# Step 1024 | Temperature: 0.0034 | Peaceful queens: 6
# Step 1025 | Temperature: 0.0034 | Peaceful queens: 6
# Step 1026 | Temperature: 0.0033 | Peaceful queens: 6
# Step 1027 | Temperature: 0.0033 | Peaceful queens: 6
# Step 1028 | Temperature: 0.0033 | Peaceful queens: 6
# Step 1029 | Temperature: 0.0032 | Peaceful queens: 6
# Step 1030 | Temperature: 0.0032 | Peaceful queens: 6
# Step 1031 | Temperature: 0.0032 | Peaceful queens: 6
# Step 1032 | Temperature: 0.0031 | Peaceful queens: 6
# Step 1033 | Temperature: 0.0031 | Peaceful queens: 6
# Step 1034 | Temperature: 0.0031 | Peaceful queens: 6
# Step 1035 | Temperature: 0.0030 | Peaceful queens: 6
# Step 1036 | Temperature: 0.0030 | Peaceful queens: 6
# Step 1037 | Temperature: 0.0030 | Peaceful queens: 6
# Step 1038 | Temperature: 0.0029 | Peaceful queens: 6
# Step 1039 | Temperature: 0.0029 | Peaceful queens: 6
# Step 1040 | Temperature: 0.0029 | Peaceful queens: 6
# Step 1041 | Temperature: 0.0029 | Peaceful queens: 6
# Step 1042 | Temperature: 0.0028 | Peaceful queens: 6
# Step 1043 | Temperature: 0.0028 | Peaceful queens: 6
# Step 1044 | Temperature: 0.0028 | Peaceful queens: 6
# Step 1045 | Temperature: 0.0027 | Peaceful queens: 6
# Step 1046 | Temperature: 0.0027 | Peaceful queens: 6
# Step 1047 | Temperature: 0.0027 | Peaceful queens: 6
# Step 1048 | Temperature: 0.0027 | Peaceful queens: 6
# Step 1049 | Temperature: 0.0026 | Peaceful queens: 6
# Step 1050 | Temperature: 0.0026 | Peaceful queens: 6
# Step 1051 | Temperature: 0.0026 | Peaceful queens: 6
# Step 1052 | Temperature: 0.0026 | Peaceful queens: 6
# Step 1053 | Temperature: 0.0025 | Peaceful queens: 6
# Step 1054 | Temperature: 0.0025 | Peaceful queens: 6
# Step 1055 | Temperature: 0.0025 | Peaceful queens: 6
# Step 1056 | Temperature: 0.0025 | Peaceful queens: 6
# Step 1057 | Temperature: 0.0024 | Peaceful queens: 6
# Step 1058 | Temperature: 0.0024 | Peaceful queens: 6
# Step 1059 | Temperature: 0.0024 | Peaceful queens: 6
# Step 1060 | Temperature: 0.0024 | Peaceful queens: 6
# Step 1061 | Temperature: 0.0023 | Peaceful queens: 6
# Step 1062 | Temperature: 0.0023 | Peaceful queens: 6
# Step 1063 | Temperature: 0.0023 | Peaceful queens: 6
# Step 1064 | Temperature: 0.0023 | Peaceful queens: 6
# Step 1065 | Temperature: 0.0022 | Peaceful queens: 6
# Step 1066 | Temperature: 0.0022 | Peaceful queens: 6
# Step 1067 | Temperature: 0.0022 | Peaceful queens: 6
# Step 1068 | Temperature: 0.0022 | Peaceful queens: 6
# Step 1069 | Temperature: 0.0022 | Peaceful queens: 6
# Step 1070 | Temperature: 0.0021 | Peaceful queens: 6
# Step 1071 | Temperature: 0.0021 | Peaceful queens: 6
# Step 1072 | Temperature: 0.0021 | Peaceful queens: 6
# Step 1073 | Temperature: 0.0021 | Peaceful queens: 6
# Step 1074 | Temperature: 0.0021 | Peaceful queens: 6
# Step 1075 | Temperature: 0.0020 | Peaceful queens: 6
# Step 1076 | Temperature: 0.0020 | Peaceful queens: 6
# Step 1077 | Temperature: 0.0020 | Peaceful queens: 6
# Step 1078 | Temperature: 0.0020 | Peaceful queens: 6
# Step 1079 | Temperature: 0.0020 | Peaceful queens: 6
# Step 1080 | Temperature: 0.0019 | Peaceful queens: 6
# Step 1081 | Temperature: 0.0019 | Peaceful queens: 6
# Step 1082 | Temperature: 0.0019 | Peaceful queens: 6
# Step 1083 | Temperature: 0.0019 | Peaceful queens: 6
# Step 1084 | Temperature: 0.0019 | Peaceful queens: 6
# Step 1085 | Temperature: 0.0018 | Peaceful queens: 6
# Step 1086 | Temperature: 0.0018 | Peaceful queens: 6
# Step 1087 | Temperature: 0.0018 | Peaceful queens: 6
# Step 1088 | Temperature: 0.0018 | Peaceful queens: 6
# Step 1089 | Temperature: 0.0018 | Peaceful queens: 6
# Step 1090 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1091 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1092 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1093 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1094 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1095 | Temperature: 0.0017 | Peaceful queens: 6
# Step 1096 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1097 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1098 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1099 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1100 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1101 | Temperature: 0.0016 | Peaceful queens: 6
# Step 1102 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1103 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1104 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1105 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1106 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1107 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1108 | Temperature: 0.0015 | Peaceful queens: 6
# Step 1109 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1110 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1111 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1112 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1113 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1114 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1115 | Temperature: 0.0014 | Peaceful queens: 6
# Step 1116 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1117 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1118 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1119 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1120 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1121 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1122 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1123 | Temperature: 0.0013 | Peaceful queens: 6
# Step 1124 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1125 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1126 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1127 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1128 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1129 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1130 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1131 | Temperature: 0.0012 | Peaceful queens: 6
# Step 1132 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1133 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1134 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1135 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1136 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1137 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1138 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1139 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1140 | Temperature: 0.0011 | Peaceful queens: 6
# Step 1141 | Temperature: 0.0010 | Peaceful queens: 6
# Step 1142 | Temperature: 0.0010 | Peaceful queens: 6
# Step 1143 | Temperature: 0.0010 | Peaceful queens: 6
# Step 1144 | Temperature: 0.0010 | Peaceful queens: 6
# Step 1145 | Temperature: 0.0010 | Peaceful queens: 6
#
# The algorithm has stopped. The final state can be a local or global maximum.
#
# Final Solution:
# Board configuration: [2, 0, 5, 1, 4, 0, 7, 3]
# Peaceful queens: 6

# %%
print_board(verbose_solution)

# %% [markdown]
# <details>
# <summary>Por que a temperatura está caindo?</summary>
#
# A temperatura cai devido a queda na pontuação. A queda na temperatura atua como a medida de "ruindade" do movimento e afeta a chance de aceitação de forma direta: **quanto maior for a queda (o tamanho do prejuízo), menor será a probabilidade de o algoritmo aceitar esse passo ruim**. Matematicamente, a fórmula ($e^{\Delta E / T}$) utiliza essa diferença negativa para reduzir a probabilidade de forma exponencial, o que significa que pequenas pioras têm grandes chances de serem perdoadas, mas pioras muito severas reduzem a probabilidade drasticamente. No entanto, o algoritmo sempre divide essa queda pela "Temperatura" atual, que funciona como um amortecedor: se a temperatura estiver alta (no início da busca), ela suaviza o impacto do tombo, permitindo que o sistema engula o prejuízo e aceite até mesmo os movimentos muito ruins para conseguir explorar novas rotas.
#
# </details>

# %% [markdown]
# ## Key Takeaways

# %% [markdown]
# *   **Compreensão da Busca Local:** Entender que algoritmos de busca local operam avaliando estados vizinhos com o objetivo de encontrar a melhor configuração final (máximo ou mínimo global) de acordo com uma função objetivo, sem se preocupar com o caminho percorrido para chegar até lá.
# *   **Flexibilidade da Função Objetivo:** Aprender que a modelagem do problema pode ser adaptada para facilitar a interpretação heurística. No problema das 8 rainhas, por exemplo, o ótimo global é alcançado maximizando o placar para 8 rainhas apaziguadas, em vez de minimizar os ataques.
# *   **Limitações do *Hill Climbing* Puro:** Reconhecer que a Subida de Encosta tradicional é um algoritmo estritamente "guloso" (*greedy*), que só aceita movimentos que melhorem imediatamente o estado atual, o que frequentemente o deixa preso em armadilhas como os máximos locais.
# *   **Estratégias de Fuga com Reinício Aleatório:** Avaliar como a variante *Random-Restart Hill Climbing* mitiga o problema dos falsos picos, reiniciando a busca a partir de posições iniciais aleatórias sempre que estagnar, aumentando drasticamente a probabilidade de sucesso.
# *   **A Intuição Termodinâmica do *Simulated Annealing*:** Compreender que o Recozimento Simulado introduz uma exploração probabilística baseada em "temperatura", permitindo que o algoritmo aceite temporariamente movimentos "ruins" (quedas na pontuação) para conseguir escapar das armadilhas dos máximos locais.
# *   **Mecânica da Regra de Aceitação:** Dominar a lógica matemática de avaliação dos vizinhos, onde $\Delta$ representa a diferença de pontuação ($\Delta = \text{score}_{vizinho} - \text{score}_{atual}$):
#     *   Movimentos de melhoria ($\Delta > 0$) são sempre aceitos imediatamente.
#     *   Movimentos de piora ($\Delta < 0$) são aceitos com base na probabilidade gerada pela fórmula de Boltzmann: $P = e^{\Delta/T}$.
# *   **O Papel do Cronograma de Resfriamento:** Entender na prática como o parâmetro "Temperatura" ($T$) atua ao longo do tempo. Uma temperatura alta no início promove a exploração livre ao aceitar muitos erros; conforme a busca avança e a temperatura cai, o algoritmo perde essa tolerância e foca no refinamento rigoroso da solução encontrada.

# %% [markdown]
# ## Referências
#
# 1. Russell, S. & Norvig, P. (2010). *Artificial Intelligence: A Modern Approach*. Prentice Hall.
# 2. Wikipedia: Hill-climbing algorithm.
# 3. Wikipedia: Simulated annealing.
# 4. GeeksforGeeks: N-Queen Problem using Hill Climbing.
